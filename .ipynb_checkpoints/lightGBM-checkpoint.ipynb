# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')
sample_submit = pd.read_csv('./data/sample_submit.csv',header=None, index_col=0)

# %%
train_df = train_df.drop(columns=['id'])
df = train_df.dropna()

X = df.drop(columns=['charges'])
y = df['charges']

X = pd.get_dummies(X)

# %%
feature_name = X.columns

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %% [markdown]
# # lightGBM

# %%
# 勾配ブースティング決定木回帰モデルの学習
from lightgbm import LGBMClassifier
nbr = LGBMClassifier(
                    learning_rate = 0.01,
                    n_estimators = 10000,
                    num_leaves = 4,
                    min_child_samples = 10)
nbr.fit(X_train, y_train,
        eval_set = (X_train, y_train), 
        early_stopping_rounds = 5, 
        verbose = 500)     # verboseは学習の様子をprintするiterationの間隔
# Out:
# Training until validation scores don't improve for 5 rounds
# [500]	training's multi_logloss: 0.294834
# [1000]	training's multi_logloss: 0.255668
# [1500]	training's multi_logloss: 0.225486
# [2000]	training's multi_logloss: 0.20291
# [2500]	training's multi_logloss: 0.184279
# [3000]	training's multi_logloss: 0.168765
# [3500]	training's multi_logloss: 0.156349
# [4000]	training's multi_logloss: 0.144901
# [4500]	training's multi_logloss: 0.134335
# [5000]	training's multi_logloss: 0.123189
# [5500]	training's multi_logloss: 0.113246
# [6000]	training's multi_logloss: 0.105185
# [6500]	training's multi_logloss: 0.0988118
# [7000]	training's multi_logloss: 0.0920803
# [7500]	training's multi_logloss: 0.0863403
# [8000]	training's multi_logloss: 0.0805237
# [8500]	training's multi_logloss: 0.0747927
# [9000]	training's multi_logloss: 0.0695317
# [9500]	training's multi_logloss: 0.0652596
# [10000]	training's multi_logloss: 0.061441
# Did not meet early stopping. Best iteration is:
# [10000]	training's multi_logloss: 0.061441
# LGBMClassifier(learning_rate=0.01, min_child_samples=10, n_estimators=10000,
#                num_leaves=4)

# %%
from sklearn.metrics import accuracy_score

# 正答率
acc_train = accuracy_score(y_train, nbr.predict(X_train))
acc_test = accuracy_score(y_test, nbr.predict(X_test))

print("acc_train: "+ str(acc_train) + "   acc_test: "+ str(acc_test))
# Out:
# acc_train: 0.990625   acc_test: 0.859375

# %%
from sklearn.metrics import f1_score

f1_train = f1_score(y_train, nbr.predict(X_train), average='macro')
f1_test = f1_score(y_test, nbr.predict(X_test), average='macro')

# 評価結果の表示
print("f1_train:", f1_train, "f1_test", f1_test)
# Out:
# f1_train: 0.9848638658961946 f1_test 0.675422593608471

# %%
import numpy as np
# 変数重要度（入力変数ごとに決定木回帰の変数重要度の平均を取ったもの）
importances = nbr.booster_.feature_importance(importance_type = "gain")
indices = np.argsort(importances)
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %%
# 変数重要度（決定木のノードにその変数が現れた数の変数重要度として出す。）
importances = nbr.booster_.feature_importance(importance_type = "split")
indices = np.argsort(importances)
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %%
# 変数重要度（feature_importances_は`gain="split"`の結果を返している。）
importances = nbr.feature_importances_
indices = np.argsort(importances)
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %% [markdown]
# ## パラメータチューニング(optuna)

# %%
from sklearn.model_selection import train_test_split, cross_validate, KFold
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from yellowbrick.model_selection import LearningCurve, ValidationCurve
import optuna

# %%
# SBMO with TPE
# 目的関数の設計
X_learn, X_val, y_learn, y_val = train_test_split(X_train, y_train, test_size = 0.2)

def objective(trial):
    # ハイパーパラメータC, gammaの探索範囲
    num_leaves = int(trial.suggest_loguniform(name = "num_leaves ", low = 2, high = 31))
    min_data_in_leaf = int(trial.suggest_loguniform(name = "min_data_in_leaf", low = 2, high = 100))
    max_depth = int(trial.suggest_loguniform(name = "max_depth", low = 1, high = 10))
    bagging_fraction = trial.suggest_loguniform(name = "bagging_fraction", low = 0.001, high = 1.0)
    bagging_freq = int(trial.suggest_loguniform(name = "bagging_freq", low = 1, high = 5))
    feature_fraction = trial.suggest_loguniform(name = "feature_fraction", low = 0.001, high = 1.0)
    
    # valデータ（検証用データ）での1-正答率
    lgbm_pra = LGBMClassifier(learning_rate = 0.01,n_estimators = 1000,
                              num_leaves = num_leaves,
                              min_data_in_leaf = min_data_in_leaf,
                              max_depth = max_depth,
                              bagging_fraction = bagging_fraction,
                              bagging_freq = bagging_freq,
                              feature_fraction = feature_fraction
                             )
    lgbm_pra.fit(X_learn, y_learn)
    y_pred = lgbm_pra.predict(X_val)
    return 1.0 - accuracy_score(y_true = y_val, y_pred = y_pred)

# %%
# ハイパーパラメータの探索
study = optuna.create_study()
study.optimize(objective, n_trials = 100)
# Out:
# [I 2021-06-23 14:56:36,383] A new study created in memory with name: no-name-1a3957cb-c833-45c9-851f-4f53632c09c8
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.015996807955073744, subsample=1.0 will be ignored. Current value: bagging_fraction=0.015996807955073744
# [LightGBM] [Warning] feature_fraction is set=0.3586454777987271, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3586454777987271
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:36,952] Trial 0 finished with value: 0.2265625 and parameters: {'num_leaves ': 12.232903570888556, 'min_data_in_leaf': 2.2295559160048812, 'max_depth': 4.060436217647361, 'bagging_fraction': 0.015996807955073744, 'bagging_freq': 2.218766049863853, 'feature_fraction': 0.3586454777987271}. Best is trial 0 with value: 0.2265625.
# [LightGBM] [Warning] min_data_in_leaf is set=90, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=90
# [LightGBM] [Warning] bagging_fraction is set=0.2873770428731348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2873770428731348
# [LightGBM] [Warning] feature_fraction is set=0.002029405473245224, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.002029405473245224
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:37,173] Trial 1 finished with value: 0.21875 and parameters: {'num_leaves ': 4.947184108908151, 'min_data_in_leaf': 90.51120806293346, 'max_depth': 2.689768421935511, 'bagging_fraction': 0.2873770428731348, 'bagging_freq': 1.2187225190515525, 'feature_fraction': 0.002029405473245224}. Best is trial 1 with value: 0.21875.
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] bagging_fraction is set=0.0598708532429809, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0598708532429809
# [LightGBM] [Warning] feature_fraction is set=0.007810237101089235, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.007810237101089235
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:37,539] Trial 2 finished with value: 0.1640625 and parameters: {'num_leaves ': 6.692424547722723, 'min_data_in_leaf': 6.042349279435554, 'max_depth': 9.575257216219828, 'bagging_fraction': 0.0598708532429809, 'bagging_freq': 2.173613535199197, 'feature_fraction': 0.007810237101089235}. Best is trial 2 with value: 0.1640625.
# [LightGBM] [Warning] min_data_in_leaf is set=22, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=22
# [LightGBM] [Warning] bagging_fraction is set=0.1221912908173569, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1221912908173569
# [LightGBM] [Warning] feature_fraction is set=0.19694443189466268, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.19694443189466268
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:37,929] Trial 3 finished with value: 0.16796875 and parameters: {'num_leaves ': 26.254387186496384, 'min_data_in_leaf': 22.498392646650704, 'max_depth': 3.3566922502740986, 'bagging_fraction': 0.1221912908173569, 'bagging_freq': 1.1911910038298001, 'feature_fraction': 0.19694443189466268}. Best is trial 2 with value: 0.1640625.
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.09486358631694736, subsample=1.0 will be ignored. Current value: bagging_fraction=0.09486358631694736
# [LightGBM] [Warning] feature_fraction is set=0.0031296069705845824, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0031296069705845824
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:38,217] Trial 4 finished with value: 0.16796875 and parameters: {'num_leaves ': 3.044454799778506, 'min_data_in_leaf': 3.57204922420493, 'max_depth': 9.039435263478378, 'bagging_fraction': 0.09486358631694736, 'bagging_freq': 1.4393353496377899, 'feature_fraction': 0.0031296069705845824}. Best is trial 2 with value: 0.1640625.
# [I 2021-06-23 14:56:38,327] Trial 5 finished with value: 0.21875 and parameters: {'num_leaves ': 8.484745010296098, 'min_data_in_leaf': 48.151159233807824, 'max_depth': 2.389464022276892, 'bagging_fraction': 0.0010308503746204757, 'bagging_freq': 3.483909875179638, 'feature_fraction': 0.024857576714197693}. Best is trial 2 with value: 0.1640625.
# [LightGBM] [Warning] min_data_in_leaf is set=48, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=48
# [LightGBM] [Warning] bagging_fraction is set=0.0010308503746204757, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0010308503746204757
# [LightGBM] [Warning] feature_fraction is set=0.024857576714197693, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.024857576714197693
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.0015911774669234511, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0015911774669234511
# [LightGBM] [Warning] feature_fraction is set=0.03798487706196359, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03798487706196359
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:38,421] Trial 6 finished with value: 0.21875 and parameters: {'num_leaves ': 2.0149624569296134, 'min_data_in_leaf': 7.446186417042268, 'max_depth': 5.703033323286975, 'bagging_fraction': 0.0015911774669234511, 'bagging_freq': 1.8222220830970608, 'feature_fraction': 0.03798487706196359}. Best is trial 2 with value: 0.1640625.
# [I 2021-06-23 14:56:38,525] Trial 7 finished with value: 0.21875 and parameters: {'num_leaves ': 12.79994935592718, 'min_data_in_leaf': 34.40005950652236, 'max_depth': 9.778611806205678, 'bagging_fraction': 0.03076264770521572, 'bagging_freq': 1.9960669913146762, 'feature_fraction': 0.0018981598531360232}. Best is trial 2 with value: 0.1640625.
# [I 2021-06-23 14:56:38,624] Trial 8 finished with value: 0.21875 and parameters: {'num_leaves ': 7.9264204955767, 'min_data_in_leaf': 29.888251608832167, 'max_depth': 8.105737222785663, 'bagging_fraction': 0.010348077592696738, 'bagging_freq': 3.879140747361974, 'feature_fraction': 0.41915218497357476}. Best is trial 2 with value: 0.1640625.
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] bagging_fraction is set=0.03076264770521572, subsample=1.0 will be ignored. Current value: bagging_fraction=0.03076264770521572
# [LightGBM] [Warning] feature_fraction is set=0.0018981598531360232, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0018981598531360232
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.010348077592696738, subsample=1.0 will be ignored. Current value: bagging_fraction=0.010348077592696738
# [LightGBM] [Warning] feature_fraction is set=0.41915218497357476, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.41915218497357476
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:38,739] Trial 9 finished with value: 0.21875 and parameters: {'num_leaves ': 5.477897993224166, 'min_data_in_leaf': 83.9179768190693, 'max_depth': 3.1286483431514998, 'bagging_fraction': 0.018155644785142373, 'bagging_freq': 1.8734100284820765, 'feature_fraction': 0.21405112737343454}. Best is trial 2 with value: 0.1640625.
# [LightGBM] [Warning] min_data_in_leaf is set=83, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=83
# [LightGBM] [Warning] bagging_fraction is set=0.018155644785142373, subsample=1.0 will be ignored. Current value: bagging_fraction=0.018155644785142373
# [LightGBM] [Warning] feature_fraction is set=0.21405112737343454, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.21405112737343454
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] bagging_fraction is set=0.795187103533682, subsample=1.0 will be ignored. Current value: bagging_fraction=0.795187103533682
# [LightGBM] [Warning] feature_fraction is set=0.015323604744104147, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.015323604744104147
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:39,009] Trial 10 finished with value: 0.15625 and parameters: {'num_leaves ': 27.72933593906595, 'min_data_in_leaf': 8.363306294320457, 'max_depth': 1.1036486532487426, 'bagging_fraction': 0.795187103533682, 'bagging_freq': 2.7801724747127143, 'feature_fraction': 0.015323604744104147}. Best is trial 10 with value: 0.15625.
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] bagging_fraction is set=0.9909957362431213, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9909957362431213
# [LightGBM] [Warning] feature_fraction is set=0.010925072350477925, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.010925072350477925
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:39,269] Trial 11 finished with value: 0.1484375 and parameters: {'num_leaves ': 23.755198207807197, 'min_data_in_leaf': 8.330388534518985, 'max_depth': 1.0597605986959138, 'bagging_fraction': 0.9909957362431213, 'bagging_freq': 2.95008609764641, 'feature_fraction': 0.010925072350477925}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.9990148359009923, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9990148359009923
# [LightGBM] [Warning] feature_fraction is set=0.02082714586131164, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.02082714586131164
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:39,516] Trial 12 finished with value: 0.15234375 and parameters: {'num_leaves ': 30.058490661398295, 'min_data_in_leaf': 10.818245185928202, 'max_depth': 1.0172061366993679, 'bagging_fraction': 0.9990148359009923, 'bagging_freq': 3.0669964913888674, 'feature_fraction': 0.02082714586131164}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.9287661291281185, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9287661291281185
# [LightGBM] [Warning] feature_fraction is set=0.06317985768701058, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06317985768701058
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:39,772] Trial 13 finished with value: 0.15625 and parameters: {'num_leaves ': 19.443653421548934, 'min_data_in_leaf': 12.466295088121264, 'max_depth': 1.0776612696286418, 'bagging_fraction': 0.9287661291281185, 'bagging_freq': 2.992639942487302, 'feature_fraction': 0.06317985768701058}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] bagging_fraction is set=0.36445218537015933, subsample=1.0 will be ignored. Current value: bagging_fraction=0.36445218537015933
# [LightGBM] [Warning] feature_fraction is set=0.005269354345376917, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.005269354345376917
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 14:56:39,999] Trial 14 finished with value: 0.15625 and parameters: {'num_leaves ': 17.59509463360612, 'min_data_in_leaf': 13.985604087559413, 'max_depth': 1.5655950665746279, 'bagging_fraction': 0.36445218537015933, 'bagging_freq': 4.432018838070083, 'feature_fraction': 0.005269354345376917}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] bagging_fraction is set=0.36802631209519227, subsample=1.0 will be ignored. Current value: bagging_fraction=0.36802631209519227
# [LightGBM] [Warning] feature_fraction is set=0.07775238924711574, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.07775238924711574
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:40,262] Trial 15 finished with value: 0.1640625 and parameters: {'num_leaves ': 30.888525861999245, 'min_data_in_leaf': 4.13910810461985, 'max_depth': 1.5790034106211748, 'bagging_fraction': 0.36802631209519227, 'bagging_freq': 2.8479319654130366, 'feature_fraction': 0.07775238924711574}. Best is trial 11 with value: 0.1484375.
# [I 2021-06-23 14:56:40,363] Trial 16 finished with value: 0.21875 and parameters: {'num_leaves ': 19.56973734891043, 'min_data_in_leaf': 18.99536670747087, 'max_depth': 1.540102322153432, 'bagging_fraction': 0.004439188696372803, 'bagging_freq': 4.816277770717152, 'feature_fraction': 0.009532112164653904}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.004439188696372803, subsample=1.0 will be ignored. Current value: bagging_fraction=0.004439188696372803
# [LightGBM] [Warning] feature_fraction is set=0.009532112164653904, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.009532112164653904
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.918182455083379, subsample=1.0 will be ignored. Current value: bagging_fraction=0.918182455083379
# [LightGBM] [Warning] feature_fraction is set=0.018031724934349083, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.018031724934349083
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:40,622] Trial 17 finished with value: 0.1484375 and parameters: {'num_leaves ': 13.277633542549559, 'min_data_in_leaf': 9.913970531832295, 'max_depth': 1.053342832940315, 'bagging_fraction': 0.918182455083379, 'bagging_freq': 3.269011637123322, 'feature_fraction': 0.018031724934349083}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.19789603039639989, subsample=1.0 will be ignored. Current value: bagging_fraction=0.19789603039639989
# [LightGBM] [Warning] feature_fraction is set=0.001048669539145655, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.001048669539145655
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:40,924] Trial 18 finished with value: 0.16796875 and parameters: {'num_leaves ': 11.806271142206924, 'min_data_in_leaf': 5.056870252459648, 'max_depth': 2.0886376246073164, 'bagging_fraction': 0.19789603039639989, 'bagging_freq': 3.870962652333878, 'feature_fraction': 0.001048669539145655}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.6165051552332256, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6165051552332256
# [LightGBM] [Warning] feature_fraction is set=0.050171324783916456, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.050171324783916456
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:41,155] Trial 19 finished with value: 0.15234375 and parameters: {'num_leaves ': 14.948427372958978, 'min_data_in_leaf': 3.51659514311737, 'max_depth': 1.3023672613200095, 'bagging_fraction': 0.6165051552332256, 'bagging_freq': 2.427938664923498, 'feature_fraction': 0.050171324783916456}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.5815103581999631, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5815103581999631
# [LightGBM] [Warning] feature_fraction is set=0.012361008977661327, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.012361008977661327
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:41,447] Trial 20 finished with value: 0.16015625 and parameters: {'num_leaves ': 9.856831258449859, 'min_data_in_leaf': 2.0671129984785535, 'max_depth': 1.8826604295795906, 'bagging_fraction': 0.5815103581999631, 'bagging_freq': 3.458992151674908, 'feature_fraction': 0.012361008977661327}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.861832761340239, subsample=1.0 will be ignored. Current value: bagging_fraction=0.861832761340239
# [LightGBM] [Warning] feature_fraction is set=0.018770260004532465, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.018770260004532465
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:41,722] Trial 21 finished with value: 0.16015625 and parameters: {'num_leaves ': 23.280602929140095, 'min_data_in_leaf': 10.579661982052894, 'max_depth': 1.012573759987996, 'bagging_fraction': 0.861832761340239, 'bagging_freq': 3.138850845522583, 'feature_fraction': 0.018770260004532465}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.4724673239077545, subsample=1.0 will be ignored. Current value: bagging_fraction=0.4724673239077545
# [LightGBM] [Warning] feature_fraction is set=0.04399895553616136, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.04399895553616136
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:41,960] Trial 22 finished with value: 0.16015625 and parameters: {'num_leaves ': 15.378361257003737, 'min_data_in_leaf': 3.4877010181928383, 'max_depth': 1.28060297057007, 'bagging_fraction': 0.4724673239077545, 'bagging_freq': 2.5036956920183893, 'feature_fraction': 0.04399895553616136}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.16715110820542006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.16715110820542006
# [LightGBM] [Warning] feature_fraction is set=0.10399159562802972, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10399159562802972
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:42,191] Trial 23 finished with value: 0.1484375 and parameters: {'num_leaves ': 14.152049815400915, 'min_data_in_leaf': 2.486296175465746, 'max_depth': 1.2965637065093232, 'bagging_fraction': 0.16715110820542006, 'bagging_freq': 2.4555314966404653, 'feature_fraction': 0.10399159562802972}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.1828768453767437, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1828768453767437
# [LightGBM] [Warning] feature_fraction is set=0.09205042958811259, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09205042958811259
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:42,439] Trial 24 finished with value: 0.16015625 and parameters: {'num_leaves ': 20.899460792823323, 'min_data_in_leaf': 2.6985850714427158, 'max_depth': 1.2829156111892106, 'bagging_fraction': 0.1828768453767437, 'bagging_freq': 1.629118284433932, 'feature_fraction': 0.09205042958811259}. Best is trial 11 with value: 0.1484375.
# [I 2021-06-23 14:56:42,652] Trial 25 finished with value: 0.1640625 and parameters: {'num_leaves ': 9.790314680152548, 'min_data_in_leaf': 18.665544030000667, 'max_depth': 1.8348985307679018, 'bagging_fraction': 0.06497491125198449, 'bagging_freq': 2.6185534005420004, 'feature_fraction': 0.8618273868130665}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.06497491125198449, subsample=1.0 will be ignored. Current value: bagging_fraction=0.06497491125198449
# [LightGBM] [Warning] feature_fraction is set=0.8618273868130665, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8618273868130665
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:42,867] Trial 26 finished with value: 0.1640625 and parameters: {'num_leaves ': 15.380004241449397, 'min_data_in_leaf': 7.95143774539572, 'max_depth': 1.2391056796635, 'bagging_fraction': 0.1605580452711001, 'bagging_freq': 4.020400968077224, 'feature_fraction': 0.11154491095476209}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.1605580452711001, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1605580452711001
# [LightGBM] [Warning] feature_fraction is set=0.11154491095476209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11154491095476209
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.2548856713811977, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2548856713811977
# [LightGBM] [Warning] feature_fraction is set=0.006059032991136442, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.006059032991136442
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:43,100] Trial 27 finished with value: 0.1640625 and parameters: {'num_leaves ': 23.74439992377077, 'min_data_in_leaf': 5.623205314539975, 'max_depth': 1.4895662481047667, 'bagging_fraction': 0.2548856713811977, 'bagging_freq': 3.4745164715918047, 'feature_fraction': 0.006059032991136442}. Best is trial 11 with value: 0.1484375.
# [I 2021-06-23 14:56:43,289] Trial 28 finished with value: 0.16796875 and parameters: {'num_leaves ': 10.9149492644629, 'min_data_in_leaf': 16.441357598750944, 'max_depth': 1.006001630484937, 'bagging_fraction': 0.048061045780267306, 'bagging_freq': 2.4027473088286713, 'feature_fraction': 0.004270507717030837}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.048061045780267306, subsample=1.0 will be ignored. Current value: bagging_fraction=0.048061045780267306
# [LightGBM] [Warning] feature_fraction is set=0.004270507717030837, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.004270507717030837
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.10969446397522789, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10969446397522789
# [LightGBM] [Warning] feature_fraction is set=0.030019730276093896, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.030019730276093896
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:43,642] Trial 29 finished with value: 0.15625 and parameters: {'num_leaves ': 13.736803741503524, 'min_data_in_leaf': 2.21628266248626, 'max_depth': 5.174455460828177, 'bagging_fraction': 0.10969446397522789, 'bagging_freq': 2.17119099717981, 'feature_fraction': 0.030019730276093896}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.5351998782844833, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5351998782844833
# [LightGBM] [Warning] feature_fraction is set=0.1458915146735916, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1458915146735916
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 14:56:43,933] Trial 30 finished with value: 0.16015625 and parameters: {'num_leaves ': 17.630364457528195, 'min_data_in_leaf': 2.623411373033566, 'max_depth': 1.1644229726697373, 'bagging_fraction': 0.5351998782844833, 'bagging_freq': 3.2504390152668963, 'feature_fraction': 0.1458915146735916}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.9813032449815554, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9813032449815554
# [LightGBM] [Warning] feature_fraction is set=0.02324253462744158, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.02324253462744158
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:44,275] Trial 31 finished with value: 0.1484375 and parameters: {'num_leaves ': 29.550315396729737, 'min_data_in_leaf': 9.35901407267102, 'max_depth': 1.0037693391754303, 'bagging_fraction': 0.9813032449815554, 'bagging_freq': 2.7880396254249686, 'feature_fraction': 0.02324253462744158}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] bagging_fraction is set=0.2937599241705435, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2937599241705435
# [LightGBM] [Warning] feature_fraction is set=0.01168321907586997, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.01168321907586997
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56:44,582] Trial 32 finished with value: 0.15625 and parameters: {'num_leaves ': 22.538554496053337, 'min_data_in_leaf': 8.391420591994914, 'max_depth': 1.005281788236627, 'bagging_fraction': 0.2937599241705435, 'bagging_freq': 2.774252871494314, 'feature_fraction': 0.01168321907586997}. Best is trial 11 with value: 0.1484375.
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] bagging_fraction is set=0.8869319529467397, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8869319529467397
# [LightGBM] [Warning] feature_fraction is set=0.03142502138883081, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03142502138883081
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 14:56
colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6262061298077337
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:49,503] Trial 41 finished with value: 0.140625 and parameters: {'num_leaves ': 8.428463979236176, 'min_data_in_leaf': 6.684195028566583, 'max_depth': 4.087114299686441, 'bagging_fraction': 0.13186698032771355, 'bagging_freq': 1.49854787410887, 'feature_fraction': 0.6262061298077337}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.1000838277807519, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1000838277807519
# [LightGBM] [Warning] feature_fraction is set=0.2667369935574124, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2667369935574124
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:50,026] Trial 42 finished with value: 0.14453125 and parameters: {'num_leaves ': 7.157993958708714, 'min_data_in_leaf': 2.7203006890711663, 'max_depth': 4.317284341808478, 'bagging_fraction': 0.1000838277807519, 'bagging_freq': 1.283888007910127, 'feature_fraction': 0.2667369935574124}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.12911697600595481, subsample=1.0 will be ignored. Current value: bagging_fraction=0.12911697600595481
# [LightGBM] [Warning] feature_fraction is set=0.26361375593837355, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.26361375593837355
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:50,562] Trial 43 finished with value: 0.15234375 and parameters: {'num_leaves ': 6.640150901439329, 'min_data_in_leaf': 2.628005717249172, 'max_depth': 4.438029195138681, 'bagging_fraction': 0.12911697600595481, 'bagging_freq': 1.2550558275122778, 'feature_fraction': 0.26361375593837355}. Best is trial 41 with value: 0.140625.
# [I 2021-06-23 14:56:50,723] Trial 44 finished with value: 0.21875 and parameters: {'num_leaves ': 4.596246072418312, 'min_data_in_leaf': 9.6482052242872, 'max_depth': 6.684212347049267, 'bagging_fraction': 0.016650048944131687, 'bagging_freq': 1.4597669225983503, 'feature_fraction': 0.582221487365308}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.016650048944131687, subsample=1.0 will be ignored. Current value: bagging_fraction=0.016650048944131687
# [LightGBM] [Warning] feature_fraction is set=0.582221487365308, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.582221487365308
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.026408374698126458, subsample=1.0 will be ignored. Current value: bagging_fraction=0.026408374698126458
# [LightGBM] [Warning] feature_fraction is set=0.2849686919372695, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2849686919372695
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:51,182] Trial 45 finished with value: 0.171875 and parameters: {'num_leaves ': 8.225976401524884, 'min_data_in_leaf': 2.950121526936766, 'max_depth': 3.5837588742019943, 'bagging_fraction': 0.026408374698126458, 'bagging_freq': 1.0883839450414659, 'feature_fraction': 0.2849686919372695}. Best is trial 41 with value: 0.140625.
# [I 2021-06-23 14:56:51,291] Trial 46 finished with value: 0.21875 and parameters: {'num_leaves ': 8.89130954613628, 'min_data_in_leaf': 12.000050568999443, 'max_depth': 4.650126393944149, 'bagging_fraction': 0.009985586176885988, 'bagging_freq': 1.930777853511885, 'feature_fraction': 0.03930956619852468}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.009985586176885988, subsample=1.0 will be ignored. Current value: bagging_fraction=0.009985586176885988
# [LightGBM] [Warning] feature_fraction is set=0.03930956619852468, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03930956619852468
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.09464505482285426, subsample=1.0 will be ignored. Current value: bagging_fraction=0.09464505482285426
# [LightGBM] [Warning] feature_fraction is set=0.1590423492796065, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1590423492796065
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:51,742] Trial 47 finished with value: 0.15625 and parameters: {'num_leaves ': 5.517672741248105, 'min_data_in_leaf': 2.0187371098781157, 'max_depth': 6.060279556636622, 'bagging_fraction': 0.09464505482285426, 'bagging_freq': 1.4431088505756322, 'feature_fraction': 0.1590423492796065}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] bagging_fraction is set=0.26171359424058116, subsample=1.0 will be ignored. Current value: bagging_fraction=0.26171359424058116
# [LightGBM] [Warning] feature_fraction is set=0.39326414589352765, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.39326414589352765
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:52,135] Trial 48 finished with value: 0.1484375 and parameters: {'num_leaves ': 7.404528041139662, 'min_data_in_leaf': 4.155787804373801, 'max_depth': 2.9935191742712277, 'bagging_fraction': 0.26171359424058116, 'bagging_freq': 1.0001855158264694, 'feature_fraction': 0.39326414589352765}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=13, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=13
# [LightGBM] [Warning] bagging_fraction is set=0.23593768234241289, subsample=1.0 will be ignored. Current value: bagging_fraction=0.23593768234241289
# [LightGBM] [Warning] feature_fraction is set=0.5300107097622268, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5300107097622268
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:52,768] Trial 49 finished with value: 0.14453125 and parameters: {'num_leaves ': 7.267821995952064, 'min_data_in_leaf': 13.732385838806582, 'max_depth': 3.445184398125169, 'bagging_fraction': 0.23593768234241289, 'bagging_freq': 1.0393009294614297, 'feature_fraction': 0.5300107097622268}. Best is trial 41 with value: 0.140625.
# [I 2021-06-23 14:56:52,943] Trial 50 finished with value: 0.21875 and parameters: {'num_leaves ': 3.9912372187737066, 'min_data_in_leaf': 24.87579771239376, 'max_depth': 3.3944180480465236, 'bagging_fraction': 0.04645587169907172, 'bagging_freq': 1.03415553787554, 'feature_fraction': 0.5879634517704627}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] bagging_fraction is set=0.04645587169907172, subsample=1.0 will be ignored. Current value: bagging_fraction=0.04645587169907172
# [LightGBM] [Warning] feature_fraction is set=0.5879634517704627, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5879634517704627
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.09303812658708842, subsample=1.0 will be ignored. Current value: bagging_fraction=0.09303812658708842
# [LightGBM] [Warning] feature_fraction is set=0.3037162514565398, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3037162514565398
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:53,546] Trial 51 finished with value: 0.14453125 and parameters: {'num_leaves ': 5.618452405432994, 'min_data_in_leaf': 7.121717219506453, 'max_depth': 3.6454265245160213, 'bagging_fraction': 0.09303812658708842, 'bagging_freq': 1.246326343187695, 'feature_fraction': 0.3037162514565398}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.08284740885652264, subsample=1.0 will be ignored. Current value: bagging_fraction=0.08284740885652264
# [LightGBM] [Warning] feature_fraction is set=0.2475143469774217, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2475143469774217
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:54,194] Trial 52 finished with value: 0.14453125 and parameters: {'num_leaves ': 5.567756647875636, 'min_data_in_leaf': 14.282857641568405, 'max_depth': 3.7535897138236622, 'bagging_fraction': 0.08284740885652264, 'bagging_freq': 1.2546358934564166, 'feature_fraction': 0.2475143469774217}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.0823332069953857, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0823332069953857
# [LightGBM] [Warning] feature_fraction is set=0.23562104353956753, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.23562104353956753
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:56:54,476] Trial 53 finished with value: 0.16015625 and parameters: {'num_leaves ': 2.5801326540953027, 'min_data_in_leaf': 14.588354218715088, 'max_depth': 3.6180085972593976, 'bagging_fraction': 0.0823332069953857, 'bagging_freq': 1.263658163639315, 'feature_fraction': 0.23562104353956753}. Best is trial 41 with value: 0.140625.
# [LightGBM] [Warning] min_data_in_leaf is set=31, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=31
# [LightGBM] [Warning] bagging_fraction is set=0.21033671860313577, subsample=1.0 will be ignored. Current value: bagging_fraction=0.21033671860313577
# ...
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] bagging_fraction is set=0.17392228960152453, subsample=1.0 will be ignored. Current value: bagging_fraction=0.17392228960152453
# [LightGBM] [Warning] feature_fraction is set=0.5624186676613881, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5624186676613881
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:07,625] Trial 82 finished with value: 0.14453125 and parameters: {'num_leaves ': 7.81214726706486, 'min_data_in_leaf': 15.936180685601558, 'max_depth': 3.758081466166065, 'bagging_fraction': 0.17392228960152453, 'bagging_freq': 1.3223916473356756, 'feature_fraction': 0.5624186676613881}. Best is trial 77 with value: 0.13671875.
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.3298975697916988, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3298975697916988
# [LightGBM] [Warning] feature_fraction is set=0.41361740464564417, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.41361740464564417
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:08,121] Trial 83 finished with value: 0.1484375 and parameters: {'num_leaves ': 5.258184415727623, 'min_data_in_leaf': 10.629205114963286, 'max_depth': 5.3750245550315565, 'bagging_fraction': 0.3298975697916988, 'bagging_freq': 1.2369596443533528, 'feature_fraction': 0.41361740464564417}. Best is trial 77 with value: 0.13671875.
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] bagging_fraction is set=0.22463547110799215, subsample=1.0 will be ignored. Current value: bagging_fraction=0.22463547110799215
# [LightGBM] [Warning] feature_fraction is set=0.5340150520826145, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5340150520826145
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:08,751] Trial 84 finished with value: 0.14453125 and parameters: {'num_leaves ': 7.814584599575682, 'min_data_in_leaf': 19.743814767205254, 'max_depth': 4.708779639688603, 'bagging_fraction': 0.22463547110799215, 'bagging_freq': 1.141974806915902, 'feature_fraction': 0.5340150520826145}. Best is trial 77 with value: 0.13671875.
# [LightGBM] [Warning] min_data_in_leaf is set=26, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=26
# [LightGBM] [Warning] bagging_fraction is set=0.1816861501396657, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1816861501396657
# [LightGBM] [Warning] feature_fraction is set=0.6597474524388259, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6597474524388259
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:09,254] Trial 85 finished with value: 0.1484375 and parameters: {'num_leaves ': 9.403801109293182, 'min_data_in_leaf': 26.71116622958388, 'max_depth': 4.058313316773553, 'bagging_fraction': 0.1816861501396657, 'bagging_freq': 1.3303455022889832, 'feature_fraction': 0.6597474524388259}. Best is trial 77 with value: 0.13671875.
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] bagging_fraction is set=0.2289340372636835, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2289340372636835
# [LightGBM] [Warning] feature_fraction is set=0.9599743162115401, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9599743162115401
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:09,884] Trial 86 finished with value: 0.14453125 and parameters: {'num_leaves ': 7.636694843833196, 'min_data_in_leaf': 19.717177921375058, 'max_depth': 6.579342318353153, 'bagging_fraction': 0.2289340372636835, 'bagging_freq': 1.1377181621543118, 'feature_fraction': 0.9599743162115401}. Best is trial 77 with value: 0.13671875.
# [LightGBM] [Warning] min_data_in_leaf is set=33, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=33
# [LightGBM] [Warning] bagging_fraction is set=0.11749863646249709, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11749863646249709
# [LightGBM] [Warning] feature_fraction is set=0.26906577746915994, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.26906577746915994
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:10,231] Trial 87 finished with value: 0.15625 and parameters: {'num_leaves ': 6.928778249533979, 'min_data_in_leaf': 33.44401910444895, 'max_depth': 3.7404170532345486, 'bagging_fraction': 0.11749863646249709, 'bagging_freq': 1.002548787631252, 'feature_fraction': 0.26906577746915994}. Best is trial 77 with value: 0.13671875.
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] bagging_fraction is set=0.2601806312119547, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2601806312119547
# [LightGBM] [Warning] feature_fraction is set=0.918759399317123, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.918759399317123
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:10,831] Trial 88 finished with value: 0.140625 and parameters: {'num_leaves ': 7.806247762190323, 'min_data_in_leaf': 20.218265768531793, 'max_depth': 8.283393773399371, 'bagging_fraction': 0.2601806312119547, 'bagging_freq': 1.1400698259373243, 'feature_fraction': 0.918759399317123}. Best is trial 77 with value: 0.13671875.
# [LightGBM] [Warning] min_data_in_leaf is set=38, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=38
# [LightGBM] [Warning] bagging_fraction is set=0.28839783671704294, subsample=1.0 will be ignored. Current value: bagging_fraction=0.28839783671704294
# [LightGBM] [Warning] feature_fraction is set=0.785968794698752, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.785968794698752
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:11,382] Trial 89 finished with value: 0.1328125 and parameters: {'num_leaves ': 9.26183135662611, 'min_data_in_leaf': 38.49951009252814, 'max_depth': 7.3121447274507565, 'bagging_fraction': 0.28839783671704294, 'bagging_freq': 1.0976577445394218, 'feature_fraction': 0.785968794698752}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=37, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=37
# [LightGBM] [Warning] bagging_fraction is set=0.7097560204002348, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7097560204002348
# [LightGBM] [Warning] feature_fraction is set=0.8248316844360145, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8248316844360145
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:12,040] Trial 90 finished with value: 0.1484375 and parameters: {'num_leaves ': 8.96436044301778, 'min_data_in_leaf': 37.72525233991174, 'max_depth': 9.018266693880731, 'bagging_fraction': 0.7097560204002348, 'bagging_freq': 1.0750368789224696, 'feature_fraction': 0.8248316844360145}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] bagging_fraction is set=0.44344266931384113, subsample=1.0 will be ignored. Current value: bagging_fraction=0.44344266931384113
# [LightGBM] [Warning] feature_fraction is set=0.593815318474121, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.593815318474121
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:12,849] Trial 91 finished with value: 0.1484375 and parameters: {'num_leaves ': 10.738980363164783, 'min_data_in_leaf': 23.374910162072734, 'max_depth': 7.6871757886227154, 'bagging_fraction': 0.44344266931384113, 'bagging_freq': 1.302511642928169, 'feature_fraction': 0.593815318474121}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] bagging_fraction is set=0.16313893291627535, subsample=1.0 will be ignored. Current value: bagging_fraction=0.16313893291627535
# [LightGBM] [Warning] feature_fraction is set=0.7519533515476353, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7519533515476353
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:13,206] Trial 92 finished with value: 0.140625 and parameters: {'num_leaves ': 8.122732328104819, 'min_data_in_leaf': 43.508636416261496, 'max_depth': 7.498768413230784, 'bagging_fraction': 0.16313893291627535, 'bagging_freq': 1.1924113065172492, 'feature_fraction': 0.7519533515476353}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] bagging_fraction is set=0.26705939354356395, subsample=1.0 will be ignored. Current value: bagging_fraction=0.26705939354356395
# [LightGBM] [Warning] feature_fraction is set=0.7435013083304409, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7435013083304409
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:13,660] Trial 93 finished with value: 0.1484375 and parameters: {'num_leaves ': 9.868708033094435, 'min_data_in_leaf': 57.324941255757594, 'max_depth': 8.347982816521215, 'bagging_fraction': 0.26705939354356395, 'bagging_freq': 1.0207071639475984, 'feature_fraction': 0.7435013083304409}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=49, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=49
# [LightGBM] [Warning] bagging_fraction is set=0.14631696067359887, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14631696067359887
# [LightGBM] [Warning] feature_fraction is set=0.9232861356477655, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9232861356477655
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:13,951] Trial 94 finished with value: 0.16015625 and parameters: {'num_leaves ': 8.348932679091124, 'min_data_in_leaf': 49.009299237215274, 'max_depth': 7.453087978273807, 'bagging_fraction': 0.14631696067359887, 'bagging_freq': 1.1242886178581617, 'feature_fraction': 0.9232861356477655}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=34, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=34
# [LightGBM] [Warning] bagging_fraction is set=0.27836225725846087, subsample=1.0 will be ignored. Current value: bagging_fraction=0.27836225725846087
# [LightGBM] [Warning] feature_fraction is set=0.37382057956526066, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.37382057956526066
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:14,476] Trial 95 finished with value: 0.1484375 and parameters: {'num_leaves ': 6.387278500759536, 'min_data_in_leaf': 34.48880873759064, 'max_depth': 8.242777121120165, 'bagging_fraction': 0.27836225725846087, 'bagging_freq': 1.0594653480344762, 'feature_fraction': 0.37382057956526066}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=46, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=46
# [LightGBM] [Warning] bagging_fraction is set=0.3867673842511426, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3867673842511426
# [LightGBM] [Warning] feature_fraction is set=0.7172450309168794, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7172450309168794
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:15,048] Trial 96 finished with value: 0.1328125 and parameters: {'num_leaves ': 9.095899517526075, 'min_data_in_leaf': 46.98835628249293, 'max_depth': 7.025543003203924, 'bagging_fraction': 0.3867673842511426, 'bagging_freq': 1.2079713717333058, 'feature_fraction': 0.7172450309168794}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=44, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=44
# [LightGBM] [Warning] bagging_fraction is set=0.53657235284281, subsample=1.0 will be ignored. Current value: bagging_fraction=0.53657235284281
# [LightGBM] [Warning] feature_fraction is set=0.9676945985978648, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9676945985978648
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:15,661] Trial 97 finished with value: 0.140625 and parameters: {'num_leaves ': 7.897195323444131, 'min_data_in_leaf': 44.00726019262434, 'max_depth': 6.49631561027214, 'bagging_fraction': 0.53657235284281, 'bagging_freq': 1.1839077893391028, 'feature_fraction': 0.9676945985978648}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=44, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=44
# [LightGBM] [Warning] bagging_fraction is set=0.5113492689087238, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5113492689087238
# [LightGBM] [Warning] feature_fraction is set=0.746741274383306, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.746741274383306
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:16,302] Trial 98 finished with value: 0.14453125 and parameters: {'num_leaves ': 8.708401700484762, 'min_data_in_leaf': 44.26708182320563, 'max_depth': 9.988785037570262, 'bagging_fraction': 0.5113492689087238, 'bagging_freq': 1.1925024193194949, 'feature_fraction': 0.746741274383306}. Best is trial 89 with value: 0.1328125.
# [LightGBM] [Warning] min_data_in_leaf is set=57, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=57
# [LightGBM] [Warning] bagging_fraction is set=0.6448099106492865, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6448099106492865
# [LightGBM] [Warning] feature_fraction is set=0.8584720858460847, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8584720858460847
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 14:57:16,993] Trial 99 finished with value: 0.140625 and parameters: {'num_leaves ': 11.951636545259385, 'min_data_in_leaf': 57.99237024525207, 'max_depth': 6.622020719882073, 'bagging_fraction': 0.6448099106492865, 'bagging_freq': 1.174673711383907, 'feature_fraction': 0.8584720858460847}. Best is trial 89 with value: 0.1328125.

# %%
# 最適なハイパーパラメータとその検証用データセットでの正答率
study.best_params, 1.0 - study.best_value
# Out:
# ({'num_leaves ': 9.26183135662611,
#   'min_data_in_leaf': 38.49951009252814,
#   'max_depth': 7.3121447274507565,
#   'bagging_fraction': 0.28839783671704294,
#   'bagging_freq': 1.0976577445394218,
#   'feature_fraction': 0.785968794698752},
#  0.8671875)

# %%
# 勾配ブースティング決定木回帰モデルの学習
from lightgbm import LGBMClassifier
nbr = LGBMClassifier(
                    learning_rate = 0.01,
                    n_estimators = 1000,
                    num_leaves = 9,
                    min_data_in_leaf = 38,
                    max_depth = 7,
                    bagging_fraction = 0.288,
                    bagging_freq = 1,
                    feature_fraction = 0.785
)
nbr.fit(X_train, y_train,
        eval_set = (X_train, y_train), 
        early_stopping_rounds = 5, 
        verbose = 500)     # verboseは学習の様子をprintするiterationの間隔
# Out:
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=38, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=38
# [LightGBM] [Warning] feature_fraction is set=0.785, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.785
# [LightGBM] [Warning] bagging_fraction is set=0.288, subsample=1.0 will be ignored. Current value: bagging_fraction=0.288
# Training until validation scores don't improve for 5 rounds
# [500]	training's multi_logloss: 0.292318
# [1000]	training's multi_logloss: 0.24316
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.24316
# LGBMClassifier(bagging_fraction=0.288, bagging_freq=1, feature_fraction=0.785,
#                learning_rate=0.01, max_depth=7, min_data_in_leaf=38,
#                n_estimators=1000, num_leaves=9)

# %%
from sklearn.metrics import f1_score

f1_train = f1_score(y_train, nbr.predict(X_train), average='macro')
f1_test = f1_score(y_test, nbr.predict(X_test), average='macro')

# 評価結果の表示
print("f1_train:", f1_train, "f1_test", f1_test)
# Out:
# f1_train: 0.8260689872062318 f1_test 0.6763521141215106

# %%
from sklearn.metrics import confusion_matrix

cm_train = confusion_matrix(y_train, nbr.predict(X_train))
cm_test = confusion_matrix(y_test, nbr.predict(X_test))

# 混同行列の表示
print(cm_train)
print(cm_test)
# Out:
# [[973  24   8]
#  [ 56  94   8]
#  [  8   8 101]]
# [[242   6   3]
#  [ 18  15   7]
#  [  1   9  19]]

# %% [markdown]
# ## 提出

# %%
test = test_df.drop(columns=['id'])

test_X = pd.get_dummies(test)
test_X.shape
# Out:
# (400, 11)

# %%
sample_submit[1] = nbr.predict(test_X)
sample_submit.to_csv('submit_lgbm_oputuna.csv', header=None)
sample_submit.head()
# Out:
#     1
# 0
# 13  0
# 23  2
# 27  0
# 28  0
# 29  0

# %% [markdown]
# ### 特徴量エンジニアリング

# %% [markdown]
# **前提** 不健康・病気がちのほうが保険料は高い

# %% [markdown]
# 仮説<br>
# - 年齢が高いほど保険費は高い
# - 男性のほうが保険費は高い
# - 喫煙者のほうが保険費は高い
# - BIMが高いほうが保険費は高い
# - 南東に住む人のほうが保険費は高い
# - 子供の有無も関係ある？

# %%
X.head()
# Out:
#    age        bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 0   26  32.665465         3           0         1          1           0
# 1   41  29.798725         1           0         1          1           0
# 2   28  32.722029         0           0         1          0           1
# 3   20  38.429831         2           1         0          1           0
# 4   45  29.641854         1           1         0          1           0
#
#    region_northeast  region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1                 0
# 1                 0                 0                 0                 1
# 2                 0                 1                 0                 0
# 3                 0                 0                 1                 0
# 4                 0                 1                 0                 0

# %%
X = X.drop(columns=['sex_female','smoker_no','region_southwest'])

# %% [markdown]
# カテゴリー変数の追加

# %%
def age_transform(x):
    if x <= 19:
        y = 0
    elif x <= 34:
        y = 1
    elif x <= 49:
        y = 2
    else:
        y = 3
    
    return y


X['generation'] = X.age.apply(lambda x: age_transform(x))

# %%
def children_transform(x):
    if x == 0:
        y = 0
    else:
        y = 1
    return y


X['have_children'] = X.children.apply(lambda x: children_transform(x))

# %%
X.head()
# Out:
#    age        bmi  children  sex_male  smoker_yes  region_northeast  \
# 0   26  32.665465         3         1           0                 0
# 1   41  29.798725         1         1           0                 0
# 2   28  32.722029         0         1           1                 0
# 3   20  38.429831         2         0           0                 0
# 4   45  29.641854         1         0           0                 0
#
#    region_northwest  region_southeast  generation  have_children
# 0                 0                 1           1              1
# 1                 0                 0           2              1
# 2                 1                 0           1              0
# 3                 0                 1           1              1
# 4                 1                 0           2              1

# %% [markdown]
# lightGBM試す

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
feature_name = X.columns

# %%
# 勾配ブースティング決定木回帰モデルの学習
from lightgbm import LGBMClassifier
nbr = LGBMClassifier(learning_rate = 0.01,
                    n_estimators = 1000,
                    num_leaves = 4,
                    min_child_samples = 10)
nbr.fit(X_train, y_train,
        eval_set = (X_train, y_train), 
        early_stopping_rounds = 5, 
        verbose = 500)     # verboseは学習の様子をprintするiterationの間隔
# Out:
# Training until validation scores don't improve for 5 rounds
# [500]	training's multi_logloss: 0.295754
# [1000]	training's multi_logloss: 0.256363
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.256363
# LGBMClassifier(learning_rate=0.01, min_child_samples=10, n_estimators=1000,
#                num_leaves=4)

# %%
from sklearn.metrics import f1_score

f1_train = f1_score(y_train, nbr.predict(X_train), average='macro')
f1_test = f1_score(y_test, nbr.predict(X_test), average='macro')

# 評価結果の表示
print("f1_train:", f1_train, "f1_test", f1_test)
# Out:
# f1_train: 0.8115017361111111 f1_test 0.6829514339241965

# %%
# 変数重要度（入力変数ごとに決定木回帰の変数重要度の平均を取ったもの）
importances = nbr.booster_.feature_importance(importance_type = "gain")
indices = np.argsort(importances)
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %%
# 変数重要度（決定木のノードにその変数が現れた数の変数重要度として出す。）
importances = nbr.booster_.feature_importance(importance_type = "split")
indices = np.argsort(importances)
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %%
# 変数重要度（feature_importances_は`gain="split"`の結果を返している。）
importances = nbr.feature_importances_
indices = np.argsort(importances)
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %% [markdown]
# 追加した変数は全く効いていない<br>
# 変数のカテゴライズは決定木においては同じこと？<br>
# 変数同士の掛け算を行うような変数を追加すべき

# %% [markdown]
# 集約（aggregation）

# %%
X.columns
# Out:
# Index(['age', 'bmi', 'children', 'sex_male', 'smoker_yes', 'region_northeast',
#        'region_northwest', 'region_southeast', 'generation', 'have_children'],
#       dtype='object')

# %%
X_children =  X.groupby(['children']).agg(children_bmi_mean=('bmi','mean'),
                                                                        children_bmi_std=('bmi', 'std'),
                                                                        children_bmi_med=('bmi', 'median'),
                                                                        children_age_mean=('age','mean'),
                                                                        children_age_std=('age', 'std'),
                                                                        children_age_med=('age','median')
                                         ).reset_index()
X = pd.merge(X, X_children, on='children', how='left')

# %%
X_children
# Out:
#    children  children_bmi_mean  children_bmi_std  children_bmi_med  \
# 0         0          32.026722          5.810841         32.044233
# 1         1          32.306045          5.650006         32.089585
# 2         2          33.501921          5.546305         33.163355
# 3         3          32.564906          5.870240         32.498988
# 4         4          31.386470          4.924951         29.186278
# 5         5          36.203007          5.884682         36.860882
#
#    children_age_mean  children_age_std  children_age_med
# 0          38.818646         15.695400              36.0
# 1          38.882857         11.029291              40.0
# 2          39.426087         10.794678              40.0
# 3          40.395210         10.751833              43.0
# 4          31.210526         12.185853              27.5
# 5          42.875000         11.569565              42.0

# %%
X_smoker =  X.groupby(['smoker_yes']).agg(
    smoker_bmi_mean=('bmi','mean'),
    smoker_bmi_std=('bmi', 'std'),
    smoker_bmi_med=('bmi', 'median'),
    smoker_age_mean=('age','mean'),
    smoker_age_std=('age', 'std'),
    smoker_age_med=('age','median')
).reset_index()

X = pd.merge(X, X_smoker, on='smoker_yes', how='left')

# %%
X_northeast =  X.groupby(['region_northeast']).agg(
    northeast_bmi_mean=('bmi','mean'),
    northeast_bmi_std=('bmi', 'std'),
    northeast_bmi_med=('bmi', 'median'),
    northeast_age_mean=('age','mean'),
    northeast_age_std=('age', 'std'),
    northeast_age_med=('age','median')
).reset_index()

X = pd.merge(X, X_northeast, on='region_northeast', how='left')

# %%
X_northwest =  X.groupby(['region_northwest']).agg(
    northwest_bmi_mean=('bmi','mean'),
    northwest_bmi_std=('bmi', 'std'),
    northwest_bmi_med=('bmi', 'median'),
    northwest_age_mean=('age','mean'),
    northwest_age_std=('age', 'std'),
    northwest_age_med=('age','median')
).reset_index()

X = pd.merge(X, X_northwest, on='region_northwest', how='left')

# %%
X_southeast =  X.groupby(['region_southeast']).agg(
    southeast_bmi_mean=('bmi','mean'),
    southeast_bmi_std=('bmi', 'std'),
    southeast_bmi_med=('bmi', 'median'),
    southeast_age_mean=('age','mean'),
    southeast_age_std=('age', 'std'),
    southeast_age_med=('age','median')
).reset_index()

X = pd.merge(X, X_southeast, on='region_southeast', how='left')

# %%
X_gen_sex =  X.groupby(['generation','sex_male']).agg(
    gen_sex_bmi_mean=('bmi','mean'),
    gen_sex_bmi_std=('bmi', 'std'),
    gen_sex_bmi_med=('bmi', 'median')
).reset_index()

X = pd.merge(X, X_gen_sex, on=['generation','sex_male'], how='left')

# %%
X_have =  X.groupby(['have_children']).agg(
    have_bmi_mean=('bmi','mean'),
    have_bmi_std=('bmi', 'std'),
    have_bmi_med=('bmi', 'median'),
    have_age_mean=('age','mean'),
    have_age_std=('age', 'std'),
    have_age_med=('age','median')
).reset_index()

X = pd.merge(X, X_have, on='have_children', how='left')

# %%
X.head()
# Out:
#    age        bmi  children  sex_male  smoker_yes  region_northeast  \
# 0   26  32.665465         3         1           0                 0
# 1   41  29.798725         1         1           0                 0
# 2   28  32.722029         0         1           1                 0
# 3   20  38.429831         2         0           0                 0
# 4   45  29.641854         1         0           0                 0
#
#    region_northwest  region_southeast  generation  have_children  ...  \
# 0                 0                 1           1              1  ...
# 1                 0                 0           2              1  ...
# 2                 1                 0           1              0  ...
# 3                 0                 1           1              1  ...
# 4                 1                 0           2              1  ...
#
#    southeast_age_med  gen_sex_bmi_mean  gen_sex_bmi_std  gen_sex_bmi_med  \
# 0                 38         31.587860         5.562149        31.891343
# 1                 40         32.509165         6.180497        31.969787
# 2                 40         31.587860         5.562149        31.891343
# 3                 38         32.419087         5.063690        32.498988
# 4                 40         32.295473         5.521102        32.048875
#
#    have_bmi_mean  have_bmi_std  have_bmi_med  have_age_mean  have_age_std  \
# 0      32.805482      5.702064     32.418405      39.144431     11.131619
# 1      32.805482      5.702064     32.418405      39.144431     11.131619
# 2      32.026722      5.810841     32.044233      38.818646     15.695400
# 3      32.805482      5.702064     32.418405      39.144431     11.131619
# 4      32.805482      5.702064     32.418405      39.144431     11.131619
#
#    have_age_med
# 0            41
# 1            41
# 2            36
# 3            41
# 4            41
#
# [5 rows x 49 columns]

# %% [markdown]
# 試す

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
feature_name = X.columns

# %%
# 勾配ブースティング決定木回帰モデルの学習
from lightgbm import LGBMClassifier
nbr = LGBMClassifier(learning_rate = 0.01,
                    n_estimators = 1000,
                    num_leaves = 4,
                    min_child_samples = 10)
nbr.fit(X_train, y_train,
        eval_set = (X_train, y_train), 
        early_stopping_rounds = 5, 
        verbose = 500)     # verboseは学習の様子をprintするiterationの間隔
# Out:
# Training until validation scores don't improve for 5 rounds
# [500]	training's multi_logloss: 0.292777
# [1000]	training's multi_logloss: 0.254003
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.254003
# LGBMClassifier(learning_rate=0.01, min_child_samples=10, n_estimators=1000,
#                num_leaves=4)

# %%
from sklearn.metrics import f1_score

f1_train = f1_score(y_train, nbr.predict(X_train), average='macro')
f1_test = f1_score(y_test, nbr.predict(X_test), average='macro')

# 評価結果の表示
print("f1_train:", f1_train, "f1_test", f1_test)
# Out:
# f1_train: 0.8152587011974245 f1_test 0.6862323423993253

# %%
X.shape
# Out:
# (1600, 49)

# %%
# 変数重要度（入力変数ごとに決定木回帰の変数重要度の平均を取ったもの）
importances = nbr.booster_.feature_importance(importance_type = "gain")
indices = np.argsort(importances)[39:]
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

cm_train = confusion_matrix(y_train, nbr.predict(X_train))
cm_test = confusion_matrix(y_test, nbr.predict(X_test))

# 混同行列の表示
print(cm_train)
print(cm_test)
# Out:
# [[973  25   7]
#  [ 59  87  12]
#  [  9   5 103]]
# [[239   8   4]
#  [ 19  14   7]
#  [  1   6  22]]

# %% [markdown]
# ## 提出

# %%
test = test_df.drop(columns=['id'])

test_X = pd.get_dummies(test)

test_X = test_X.drop(columns=['sex_female','smoker_no','region_southwest'])

test_X['generation'] = test_X.age.apply(lambda x: age_transform(x))
test_X['have_children'] = test_X.children.apply(lambda x: children_transform(x))

test_X_children =  test_X.groupby(['children']).agg(children_bmi_mean=('bmi','mean'),
                                                                        children_bmi_std=('bmi', 'std'),
                                                                        children_bmi_med=('bmi', 'median'),
                                                                        children_age_mean=('age','mean'),
                                                                        children_age_std=('age', 'std'),
                                                                        children_age_med=('age','median')
                                         ).reset_index()
test_X = pd.merge(test_X, test_X_children, on='children', how='left')

test_X_smoker =  test_X.groupby(['smoker_yes']).agg(
    smoker_bmi_mean=('bmi','mean'),
    smoker_bmi_std=('bmi', 'std'),
    smoker_bmi_med=('bmi', 'median'),
    smoker_age_mean=('age','mean'),
    smoker_age_std=('age', 'std'),
    smoker_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_smoker, on='smoker_yes', how='left')

test_X_northeast =  test_X.groupby(['region_northeast']).agg(
    northeast_bmi_mean=('bmi','mean'),
    northeast_bmi_std=('bmi', 'std'),
    northeast_bmi_med=('bmi', 'median'),
    northeast_age_mean=('age','mean'),
    northeast_age_std=('age', 'std'),
    northeast_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_northeast, on='region_northeast', how='left')

test_X_northwest =  test_X.groupby(['region_northwest']).agg(
    northwest_bmi_mean=('bmi','mean'),
    northwest_bmi_std=('bmi', 'std'),
    northwest_bmi_med=('bmi', 'median'),
    northwest_age_mean=('age','mean'),
    northwest_age_std=('age', 'std'),
    northwest_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_northwest, on='region_northwest', how='left')

test_X_southeast =  test_X.groupby(['region_southeast']).agg(
    southeast_bmi_mean=('bmi','mean'),
    southeast_bmi_std=('bmi', 'std'),
    southeast_bmi_med=('bmi', 'median'),
    southeast_age_mean=('age','mean'),
    southeast_age_std=('age', 'std'),
    southeast_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_southeast, on='region_southeast', how='left')

test_X_gen_sex =  test_X.groupby(['generation','sex_male']).agg(
    gen_sex_bmi_mean=('bmi','mean'),
    gen_sex_bmi_std=('bmi', 'std'),
    gen_sex_bmi_med=('bmi', 'median')
).reset_index()

test_X = pd.merge(test_X, test_X_gen_sex, on=['generation','sex_male'], how='left')

test_X_have =  test_X.groupby(['have_children']).agg(
    have_bmi_mean=('bmi','mean'),
    have_bmi_std=('bmi', 'std'),
    have_bmi_med=('bmi', 'median'),
    have_age_mean=('age','mean'),
    have_age_std=('age', 'std'),
    have_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_have, on='have_children', how='left')


test_X.shape
# Out:
# (400, 49)

# %%
sample_submit[1] = nbr.predict(test_X)
sample_submit.to_csv('submit_lgbm_overfitting.csv', header=None)
sample_submit.head()
# Out:
#     1
# 0
# 13  0
# 23  2
# 27  0
# 28  0
# 29  0

# %%
#パラメータ調整

def objective(trial):
    # ハイパーパラメータの探索範囲
    num_leaves = int(trial.suggest_loguniform(name = "num_leaves ", low = 2, high = 50))
    min_data_in_leaf = int(trial.suggest_loguniform(name = "min_data_in_leaf", low = 2, high = 100))
    max_depth = int(trial.suggest_loguniform(name = "max_depth", low = 1, high = 10))
    bagging_fraction = trial.suggest_loguniform(name = "bagging_fraction", low = 0.001, high = 1.0)
    bagging_freq = int(trial.suggest_loguniform(name = "bagging_freq", low = 1, high = 5))
    feature_fraction = trial.suggest_loguniform(name = "feature_fraction", low = 0.001, high = 1.0)
    
    # valデータ（検証用データ）での1-正答率
    lgbm_pra = LGBMClassifier(learning_rate = 0.01,n_estimators = 1000,
                              num_leaves = num_leaves,
                              min_data_in_leaf = min_data_in_leaf,
                              max_depth = max_depth,
                              bagging_fraction = bagging_fraction,
                              bagging_freq = bagging_freq,
                              feature_fraction = feature_fraction
                             )
    lgbm_pra.fit(X_train, y_train)
    y_pred = lgbm_pra.predict(X_test)
    return 1.0 - accuracy_score(y_true = y_test, y_pred = y_test)

# %%
# ハイパーパラメータの探索
study = optuna.create_study()
study.optimize(objective, n_trials = 200)
# Out:
# [I 2021-06-23 15:16:13,190] A new study created in memory with name: no-name-cc3ce0b4-03fc-44a2-a3af-082ff4d58e4f
# [I 2021-06-23 15:16:13,391] Trial 0 finished with value: 0.0 and parameters: {'num_leaves ': 11.070313153975668, 'min_data_in_leaf': 54.438228867000234, 'max_depth': 1.9106163322573242, 'bagging_fraction': 0.011186138854175218, 'bagging_freq': 1.1600243875309322, 'feature_fraction': 0.14167845037624854}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=54, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=54
# [LightGBM] [Warning] bagging_fraction is set=0.011186138854175218, subsample=1.0 will be ignored. Current value: bagging_fraction=0.011186138854175218
# [LightGBM] [Warning] feature_fraction is set=0.14167845037624854, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.14167845037624854
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=37, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=37
# [LightGBM] [Warning] bagging_fraction is set=0.0012233854458845133, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0012233854458845133
# [LightGBM] [Warning] feature_fraction is set=0.007007933176676698, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.007007933176676698
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:13,529] Trial 1 finished with value: 0.0 and parameters: {'num_leaves ': 4.717439618754489, 'min_data_in_leaf': 37.577400650956946, 'max_depth': 5.86966591250659, 'bagging_fraction': 0.0012233854458845133, 'bagging_freq': 1.5362891788231912, 'feature_fraction': 0.007007933176676698}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] bagging_fraction is set=0.3239122323137866, subsample=1.0 will be ignored. Current value: bagging_fraction=0.3239122323137866
# [LightGBM] [Warning] feature_fraction is set=0.008985433940854142, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.008985433940854142
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:13,893] Trial 2 finished with value: 0.0 and parameters: {'num_leaves ': 11.322822048990034, 'min_data_in_leaf': 4.59080826098923, 'max_depth': 6.929729356277367, 'bagging_fraction': 0.3239122323137866, 'bagging_freq': 4.897813423067433, 'feature_fraction': 0.008985433940854142}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:14,085] Trial 3 finished with value: 0.0 and parameters: {'num_leaves ': 2.101267781588457, 'min_data_in_leaf': 7.796584334969334, 'max_depth': 3.38966025292737, 'bagging_fraction': 0.010649060968285735, 'bagging_freq': 1.1831729397209487, 'feature_fraction': 0.14484303061556428}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.010649060968285735, subsample=1.0 will be ignored. Current value: bagging_fraction=0.010649060968285735
# [LightGBM] [Warning] feature_fraction is set=0.14484303061556428, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.14484303061556428
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] bagging_fraction is set=0.007860963268898541, subsample=1.0 will be ignored. Current value: bagging_fraction=0.007860963268898541
# [LightGBM] [Warning] feature_fraction is set=0.012199408215395629, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.012199408215395629
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:14,240] Trial 4 finished with value: 0.0 and parameters: {'num_leaves ': 3.1292269169935136, 'min_data_in_leaf': 23.068563129982216, 'max_depth': 2.2640008948961428, 'bagging_fraction': 0.007860963268898541, 'bagging_freq': 1.7917126560360306, 'feature_fraction': 0.012199408215395629}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:14,371] Trial 5 finished with value: 0.0 and parameters: {'num_leaves ': 34.891726278828806, 'min_data_in_leaf': 12.105060182062246, 'max_depth': 4.599289316381591, 'bagging_fraction': 0.010941077456129296, 'bagging_freq': 4.281176932663866, 'feature_fraction': 0.03671393965867438}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=12, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=12
# [LightGBM] [Warning] bagging_fraction is set=0.010941077456129296, subsample=1.0 will be ignored. Current value: bagging_fraction=0.010941077456129296
# [LightGBM] [Warning] feature_fraction is set=0.03671393965867438, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03671393965867438
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_data_in_leaf is set=98, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=98
# [LightGBM] [Warning] bagging_fraction is set=0.0025688720407186327, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0025688720407186327
# [LightGBM] [Warning] feature_fraction is set=0.6043966535906058, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6043966535906058
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:14,528] Trial 6 finished with value: 0.0 and parameters: {'num_leaves ': 5.140683918078129, 'min_data_in_leaf': 98.15145252756216, 'max_depth': 3.903359002783733, 'bagging_fraction': 0.0025688720407186327, 'bagging_freq': 2.1448808736559006, 'feature_fraction': 0.6043966535906058}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:14,636] Trial 7 finished with value: 0.0 and parameters: {'num_leaves ': 6.4335068272833675, 'min_data_in_leaf': 9.07058635107343, 'max_depth': 2.248411730644527, 'bagging_fraction': 0.0017641415323270107, 'bagging_freq': 1.640599450589223, 'feature_fraction': 0.006864492837292953}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.0017641415323270107, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0017641415323270107
# [LightGBM] [Warning] feature_fraction is set=0.006864492837292953, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.006864492837292953
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.27040636562718795, subsample=1.0 will be ignored. Current value: bagging_fraction=0.27040636562718795
# [LightGBM] [Warning] feature_fraction is set=0.39742890656717594, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.39742890656717594
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:15,095] Trial 8 finished with value: 0.0 and parameters: {'num_leaves ': 5.697878975648265, 'min_data_in_leaf': 11.439566641616818, 'max_depth': 1.8080670588800853, 'bagging_fraction': 0.27040636562718795, 'bagging_freq': 1.0720879095320377, 'feature_fraction': 0.39742890656717594}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=76, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=76
# [LightGBM] [Warning] bagging_fraction is set=0.34667152145229957, subsample=1.0 will be ignored. Current value: bagging_fraction=0.34667152145229957
# [LightGBM] [Warning] feature_fraction is set=0.018916688756678603, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.018916688756678603
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:15,400] Trial 9 finished with value: 0.0 and parameters: {'num_leaves ': 2.870451198977194, 'min_data_in_leaf': 76.70006196938094, 'max_depth': 1.8005972673078088, 'bagging_fraction': 0.34667152145229957, 'bagging_freq': 1.8017498408569872, 'feature_fraction': 0.018916688756678603}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:15,542] Trial 10 finished with value: 0.0 and parameters: {'num_leaves ': 19.042611447455425, 'min_data_in_leaf': 54.35534164761364, 'max_depth': 1.014437074468149, 'bagging_fraction': 0.06244242989042844, 'bagging_freq': 3.1665037956753737, 'feature_fraction': 0.0014626853099781033}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=54, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=54
# [LightGBM] [Warning] bagging_fraction is set=0.06244242989042844, subsample=1.0 will be ignored. Current value: bagging_fraction=0.06244242989042844
# [LightGBM] [Warning] feature_fraction is set=0.0014626853099781033, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0014626853099781033
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_data_in_leaf is set=32, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=32
# [LightGBM] [Warning] bagging_fraction is set=0.0011067512130972558, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0011067512130972558
# [LightGBM] [Warning] feature_fraction is set=0.08521550709943396, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08521550709943396
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:15,738] Trial 11 finished with value: 0.0 and parameters: {'num_leaves ': 12.255757958205628, 'min_data_in_leaf': 32.63936712186759, 'max_depth': 8.803913402827112, 'bagging_fraction': 0.0011067512130972558, 'bagging_freq': 1.2540464274521648, 'feature_fraction': 0.08521550709943396}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:15,932] Trial 12 finished with value: 0.0 and parameters: {'num_leaves ': 19.00778944937105, 'min_data_in_leaf': 36.81058391762202, 'max_depth': 1.0251147081844523, 'bagging_fraction': 0.05519988816691735, 'bagging_freq': 1.4125159281180386, 'feature_fraction': 0.0018675090323946012}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=36, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=36
# [LightGBM] [Warning] bagging_fraction is set=0.05519988816691735, subsample=1.0 will be ignored. Current value: bagging_fraction=0.05519988816691735
# [LightGBM] [Warning] feature_fraction is set=0.0018675090323946012, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0018675090323946012
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] bagging_fraction is set=0.0038272042875424905, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0038272042875424905
# [LightGBM] [Warning] feature_fraction is set=0.13884206749631547, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.13884206749631547
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:16,083] Trial 13 finished with value: 0.0 and parameters: {'num_leaves ': 7.825970365524861, 'min_data_in_leaf': 21.080086752507505, 'max_depth': 6.710870927014299, 'bagging_fraction': 0.0038272042875424905, 'bagging_freq': 1.0049710662640132, 'feature_fraction': 0.13884206749631547}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16
colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06531787806717071
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:17,678] Trial 21 finished with value: 0.0 and parameters: {'num_leaves ': 25.128090023270865, 'min_data_in_leaf': 3.949802642957948, 'max_depth': 2.912150543498119, 'bagging_fraction': 0.1174831567034843, 'bagging_freq': 2.513351566761428, 'feature_fraction': 0.06531787806717071}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.13247881614876475, subsample=1.0 will be ignored. Current value: bagging_fraction=0.13247881614876475
# [LightGBM] [Warning] feature_fraction is set=0.1922829641078878, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1922829641078878
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:18,023] Trial 22 finished with value: 0.0 and parameters: {'num_leaves ': 43.56440033566072, 'min_data_in_leaf': 2.2879836629703747, 'max_depth': 1.3130318460984456, 'bagging_fraction': 0.13247881614876475, 'bagging_freq': 1.1885911663977613, 'feature_fraction': 0.1922829641078878}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:18,147] Trial 23 finished with value: 0.0 and parameters: {'num_leaves ': 8.51924408535449, 'min_data_in_leaf': 19.402452769764547, 'max_depth': 1.348905275219418, 'bagging_fraction': 0.017821488863436343, 'bagging_freq': 3.5870143470327958, 'feature_fraction': 0.8907269613495842}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] bagging_fraction is set=0.017821488863436343, subsample=1.0 will be ignored. Current value: bagging_fraction=0.017821488863436343
# [LightGBM] [Warning] feature_fraction is set=0.8907269613495842, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8907269613495842
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] bagging_fraction is set=0.8431491121145807, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8431491121145807
# [LightGBM] [Warning] feature_fraction is set=0.08358573995306583, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08358573995306583
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:18,862] Trial 24 finished with value: 0.0 and parameters: {'num_leaves ': 24.6139974542895, 'min_data_in_leaf': 4.398237220536687, 'max_depth': 3.647935208169237, 'bagging_fraction': 0.8431491121145807, 'bagging_freq': 2.364922113062092, 'feature_fraction': 0.08358573995306583}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.13895467397836248, subsample=1.0 will be ignored. Current value: bagging_fraction=0.13895467397836248
# [LightGBM] [Warning] feature_fraction is set=0.1688044207333112, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1688044207333112
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:19,152] Trial 25 finished with value: 0.0 and parameters: {'num_leaves ': 29.04075815585059, 'min_data_in_leaf': 3.6733683587955994, 'max_depth': 1.7252997367727465, 'bagging_fraction': 0.13895467397836248, 'bagging_freq': 2.1869331926779574, 'feature_fraction': 0.1688044207333112}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:19,366] Trial 26 finished with value: 0.0 and parameters: {'num_leaves ': 15.019773622028916, 'min_data_in_leaf': 6.669821736522405, 'max_depth': 1.2447713705028127, 'bagging_fraction': 0.01538531603600825, 'bagging_freq': 3.8078105474793795, 'feature_fraction': 0.9801820715961811}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] bagging_fraction is set=0.01538531603600825, subsample=1.0 will be ignored. Current value: bagging_fraction=0.01538531603600825
# [LightGBM] [Warning] feature_fraction is set=0.9801820715961811, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9801820715961811
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_data_in_leaf is set=14, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=14
# [LightGBM] [Warning] bagging_fraction is set=0.9562091676452561, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9562091676452561
# [LightGBM] [Warning] feature_fraction is set=0.023449434616650083, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.023449434616650083
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:19,741] Trial 27 finished with value: 0.0 and parameters: {'num_leaves ': 8.831726159564967, 'min_data_in_leaf': 14.954037418331852, 'max_depth': 2.185041881484842, 'bagging_fraction': 0.9562091676452561, 'bagging_freq': 4.971154479591339, 'feature_fraction': 0.023449434616650083}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.8992631742170012, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8992631742170012
# [LightGBM] [Warning] feature_fraction is set=0.10536747066644002, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10536747066644002
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:20,219] Trial 28 finished with value: 0.0 and parameters: {'num_leaves ': 27.949817859945778, 'min_data_in_leaf': 3.353085509518525, 'max_depth': 1.6858542640910117, 'bagging_fraction': 0.8992631742170012, 'bagging_freq': 2.1226125686589263, 'feature_fraction': 0.10536747066644002}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] bagging_fraction is set=0.049870959026483246, subsample=1.0 will be ignored. Current value: bagging_fraction=0.049870959026483246
# [LightGBM] [Warning] feature_fraction is set=0.23684303080372082, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.23684303080372082
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:20,491] Trial 29 finished with value: 0.0 and parameters: {'num_leaves ': 12.521858520308914, 'min_data_in_leaf': 6.492792888876915, 'max_depth': 1.1175435635613749, 'bagging_fraction': 0.049870959026483246, 'bagging_freq': 4.2428392420845995, 'feature_fraction': 0.23684303080372082}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:20,674] Trial 30 finished with value: 0.0 and parameters: {'num_leaves ': 14.317937116229372, 'min_data_in_leaf': 6.0451726724040284, 'max_depth': 2.2036203234522866, 'bagging_fraction': 0.006526387132343085, 'bagging_freq': 3.8295388698966337, 'feature_fraction': 0.022817730365636852}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] bagging_fraction is set=0.006526387132343085, subsample=1.0 will be ignored. Current value: bagging_fraction=0.006526387132343085
# [LightGBM] [Warning] feature_fraction is set=0.022817730365636852, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.022817730365636852
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.6365885365508369, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6365885365508369
# [LightGBM] [Warning] feature_fraction is set=0.021479117562562187, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.021479117562562187
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:20,937] Trial 31 finished with value: 0.0 and parameters: {'num_leaves ': 16.171503907675536, 'min_data_in_leaf': 2.75684533634413, 'max_depth': 1.5247728862034284, 'bagging_fraction': 0.6365885365508369, 'bagging_freq': 4.953415618669297, 'feature_fraction': 0.021479117562562187}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.9222236643836669, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9222236643836669
# [LightGBM] [Warning] feature_fraction is set=0.10477028659498865, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.10477028659498865
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:21,380] Trial 32 finished with value: 0.0 and parameters: {'num_leaves ': 10.342286382830366, 'min_data_in_leaf': 2.998677464172828, 'max_depth': 1.9844790072705554, 'bagging_fraction': 0.9222236643836669, 'bagging_freq': 4.3451141892630885, 'feature_fraction': 0.10477028659498865}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.00811409075129184, subsample=1.0 will be ignored. Current value: bagging_fraction=0.00811409075129184
# [LightGBM] [Warning] feature_fraction is set=0.25888929817581713, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.25888929817581713
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:21,607] Trial 33 finished with value: 0.0 and parameters: {'num_leaves ': 14.09592599164298, 'min_data_in_leaf': 5.519528344765728, 'max_depth': 1.5846737698271889, 'bagging_fraction': 0.00811409075129184, 'bagging_freq': 4.303600482059856, 'feature_fraction': 0.25888929817581713}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:21,756] Trial 34 finished with value: 0.0 and parameters: {'num_leaves ': 12.14071806165996, 'min_data_in_leaf': 5.730479076364589, 'max_depth': 1.0952583294290918, 'bagging_fraction': 0.006271373228795842, 'bagging_freq': 4.6380907771797855, 'feature_fraction': 0.013133069797747926}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.006271373228795842, subsample=1.0 will be ignored. Current value: bagging_fraction=0.006271373228795842
# [LightGBM] [Warning] feature_fraction is set=0.013133069797747926, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.013133069797747926
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.029400299843310673, subsample=1.0 will be ignored. Current value: bagging_fraction=0.029400299843310673
# [LightGBM] [Warning] feature_fraction is set=0.5282133555455228, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5282133555455228
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 15:16:21,926] Trial 35 finished with value: 0.0 and parameters: {'num_leaves ': 42.441492813229374, 'min_data_in_leaf': 29.93435661362809, 'max_depth': 2.8549940598185537, 'bagging_fraction': 0.029400299843310673, 'bagging_freq': 3.1168562285000885, 'feature_fraction': 0.5282133555455228}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.14000964392027587, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14000964392027587
# [LightGBM] [Warning] feature_fraction is set=0.06386159867061163, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06386159867061163
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:22,432] Trial 36 finished with value: 0.0 and parameters: {'num_leaves ': 6.928666894919965, 'min_data_in_leaf': 2.4839230096823854, 'max_depth': 9.734574717581692, 'bagging_fraction': 0.14000964392027587, 'bagging_freq': 1.1288153139953636, 'feature_fraction': 0.06386159867061163}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=26, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=26
# [LightGBM] [Warning] bagging_fraction is set=0.10621759698330327, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10621759698330327
# [LightGBM] [Warning] feature_fraction is set=0.1780793695949396, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1780793695949396
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:22,918] Trial 37 finished with value: 0.0 and parameters: {'num_leaves ': 49.40728363503488, 'min_data_in_leaf': 26.24533575955124, 'max_depth': 4.048724571525026, 'bagging_fraction': 0.10621759698330327, 'bagging_freq': 1.9018270677719538, 'feature_fraction': 0.1780793695949396}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=15, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=15
# [LightGBM] [Warning] bagging_fraction is set=0.21908588988330907, subsample=1.0 will be ignored. Current value: bagging_fraction=0.21908588988330907
# [LightGBM] [Warning] feature_fraction is set=0.055633168318798595, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.055633168318798595
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:23,714] Trial 38 finished with value: 0.0 and parameters: {'num_leaves ': 29.71686132348525, 'min_data_in_leaf': 15.54802835695715, 'max_depth': 3.262955217780997, 'bagging_fraction': 0.21908588988330907, 'bagging_freq': 2.5522333250253073, 'feature_fraction': 0.055633168318798595}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=8, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=8
# [LightGBM] [Warning] bagging_fraction is set=0.08123359790232101, subsample=1.0 will be ignored. Current value: bagging_fraction=0.08123359790232101
# [LightGBM] [Warning] feature_fraction is set=0.5312642045422912, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5312642045422912
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:24,208] Trial 39 finished with value: 0.0 and parameters: {'num_leaves ': 23.927403768656905, 'min_data_in_leaf': 8.624120545078252, 'max_depth': 1.2463755173030524, 'bagging_fraction': 0.08123359790232101, 'bagging_freq': 1.6200639557523997, 'feature_fraction': 0.5312642045422912}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] bagging_fraction is set=0.012728465349471354, subsample=1.0 will be ignored. Current value: bagging_fraction=0.012728465349471354
# [LightGBM] [Warning] feature_fraction is set=0.7264033208983727, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7264033208983727
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:24,660] Trial 40 finished with value: 0.0 and parameters: {'num_leaves ': 9.767509093323211, 'min_data_in_leaf': 4.236785266060138, 'max_depth': 3.9538380420967614, 'bagging_fraction': 0.012728465349471354, 'bagging_freq': 1.2098259911388196, 'feature_fraction': 0.7264033208983727}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.016356359765626757, subsample=1.0 will be ignored. Current value: bagging_fraction=0.016356359765626757
# [LightGBM] [Warning] feature_fraction is set=0.18053026124843588, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.18053026124843588
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:24,905] Trial 41 finished with value: 0.0 and parameters: {'num_leaves ': 32.900546359034124, 'min_data_in_leaf': 3.5060169214899997, 'max_depth': 1.935759285400479, 'bagging_fraction': 0.016356359765626757, 'bagging_freq': 2.2833858230368462, 'feature_fraction': 0.18053026124843588}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] bagging_fraction is set=0.015048011968667665, subsample=1.0 will be ignored. Current value: bagging_fraction=0.015048011968667665
# [LightGBM] [Warning] feature_fraction is set=0.9017895585441287, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9017895585441287
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 15:16:25,166] Trial 42 finished with value: 0.0 and parameters: {'num_leaves ': 15.609474263443111, 'min_data_in_leaf': 4.880412965560981, 'max_depth': 1.2068090060873098, 'bagging_fraction': 0.015048011968667665, 'bagging_freq': 3.5767994773809137, 'feature_fraction': 0.9017895585441287}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.03596153570047908, subsample=1.0 will be ignored. Current value: bagging_fraction=0.03596153570047908
# [LightGBM] [Warning] feature_fraction is set=0.42890988643481737, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.42890988643481737
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [I 2021-06-23 15:16:25,587] Trial 43 finished with value: 0.0 and parameters: {'num_leaves ': 21.311087708212387, 'min_data_in_leaf': 11.887197498049305, 'max_depth': 2.4177680845786917, 'bagging_fraction': 0.03596153570047908, 'bagging_freq': 3.8261103728747403, 'feature_fraction': 0.42890988643481737}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=9, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=9
# [LightGBM] [Warning] bagging_fraction is set=0.5138864247287204, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5138864247287204
# [LightGBM] [Warning] feature_fraction is set=0.032134496551425355, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.032134496551425355
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:26,183] Trial 44 finished with value: 0.0 and parameters: {'num_leaves ': 23.02550386572332, 'min_data_in_leaf': 9.901896823711047, 'max_depth': 3.5918044299114165, 'bagging_fraction': 0.5138864247287204, 'bagging_freq': 1.9526318533792553, 'feature_fraction': 0.032134496551425355}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.40996243688908285, subsample=1.0 will be ignored. Current value: bagging_fraction=0.40996243688908285
# [LightGBM] [Warning] feature_fraction is set=0.011877321214154784, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.011877321214154784
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:16:26,592] Trial 45 finished with value: 0.0 and parameters: {'num_leaves ': 10.314726505065805, 'min_data_in_leaf': 7.726047752236567, 'max_depth': 2.4534054178791225, 'bagging_fraction': 0.40996243688908285, 'bagging_freq': 2.858390948997784, 'feature_fraction': 0.011877321214154784}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:26,724] Trial 46 finished with value: 0.0 and parameters: {'num_leaves ': 28.658509301099475, 'min_data_in_leaf': 16.60156850797484, 'max_depth': 1.654441722480858, 'bagging_fraction': 0.009999910409569367, 'bagging_freq': 2.1314087846151, 'feature_fraction': 0.11458253511072657}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.009999910409569367, subsample=1.0 will be ignored. Current value: bagging_fraction=0.009999910409569367
# [LightGBM] [Warning] feature_fraction is set=0.11458253511072657, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11458253511072657
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.23489842147928094, subsample=1.0 will be ignored. Current value: bagging_fraction=0.23489842147928094
# [LightGBM] [Warning] feature_fraction is set=0.04270638447637843, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.04270638447637843
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:16:27,093] Trial 47 finished with value: 0.0 and parameters: {'num_leaves ': 5.764328633125266, 'min_data_in_leaf': 2.9912087213561187, 'max_depth': 1.7823042086358305, 'bagging_fraction': 0.23489842147928094, 'bagging_freq': 1.96782298417842, 'feature_fraction': 0.04270638447637843}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=0.060539367580137365, subsample=1.0 will be ignored. Current value: bagging_fraction=0.060539367580137365
# [LightGBM] [Warning] feature_fraction is set=0.26980185095781156, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.26980185095781156
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:27,380] Trial 48 finished with value: 0.0 and parameters: {'num_leaves ': 12.915380613474554, 'min_data_in_leaf': 7.043540622577881, 'max_depth': 1.1251054700950067, 'bagging_fraction': 0.060539367580137365, 'bagging_freq': 4.555527233534985, 'feature_fraction': 0.26980185095781156}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:27,506] Trial 49 finished with value: 0.0 and parameters: {'num_leaves ': 6.957386558560266, 'min_data_in_leaf': 10.19360750735404, 'max_depth': 1.4983217369755142, 'bagging_fraction': 0.0019983396876260993, 'bagging_freq': 3.925798507799158, 'feature_fraction': 0.09165140673864257}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] bagging_fraction is set=0.0019983396876260993, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0019983396876260993
# [LightGBM] [Warning] feature_fraction is set=0.09165140673864257, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.09165140673864257
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.005009093508061087, subsample=1.0 will be ignored. Current value: bagging_fraction=0.005009093508061087
# [LightGBM] [Warning] feature_fraction is set=0.01945827185472013, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.01945827185472013
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:27,644] Trial 50 finished with value: 0.0 and parameters: {'num_leaves ': 8.505213176113658, 'min_data_in_leaf': 5.774013934714228, 'max_depth': 1.9704723412748952, 'bagging_fraction': 0.005009093508061087, 'bagging_freq': 4.928371677878829, 'feature_fraction': 0.01945827185472013}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.5777816996446133, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5777816996446133
# [LightGBM] [Warning] feature_fraction is set=0.019714882945799407, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.019714882945799407
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:27,981] Trial 51 finished with value: 0.0 and parameters: {'num_leaves ': 16.5326636684054, 'min_data_in_leaf': 2.815120471017189, 'max_depth': 2.127847697749666, 'bagging_fraction': 0.5777816996446133, 'bagging_freq': 4.7338860863022765, 'feature_fraction': 0.019714882945799407}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] bagging_fraction is set=0.7276775846621921, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7276775846621921
# [LightGBM] [Warning] feature_fraction is set=0.1163029138018891, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.1163029138018891
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [I 2021-06-23 15:16:28,452] Trial 52 finished with value: 0.0 and parameters: {'num_leaves ': 10.84211297889508, 'min_data_in_leaf': 3.1314723132793376, 'max_depth': 1.9747132796448368, 'bagging_fraction': 0.7276775846621921, 'bagging_freq': 4.316673764388903, 'feature_fraction': 0.1163029138018891}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:16:28,666] Trial 53 finished with value: 0.0 and parameters: {'num_leaves ': 12.244205908585757, 'min_data_in_leaf': 2.7204848228023932, 'max_depth': 1.4427071725449094, 'bagging_fraction': 0.0026894075830558523, 'bagging_freq': 4.1445678913976725, 'feature_fraction': 0.005424128034028584}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.0026894075830558523, subsample=1.0 will be ignored. Current value: bagging_fraction=0.0026894075830558523
# [LightGBM] [Warning] feature_fraction is set=0.005424128034028584, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.005424128034028584
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.007097819440730596, subsample=1.0 will be ignored. Current value: bagging_fraction=0.007097819440730596
# [LightGBM] [Warning] feature_fraction is set=0.2397951513383579, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2397951513383579
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# ...
# [LightGBM] [Warning] feature_fraction is set=0.04057246116081596, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.04057246116081596
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=37, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=37
# [LightGBM] [Warning] bagging_fraction is set=0.023631181441602766, subsample=1.0 will be ignored. Current value: bagging_fraction=0.023631181441602766
# [LightGBM] [Warning] feature_fraction is set=0.0770080221267695, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0770080221267695
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:17:02,444] Trial 182 finished with value: 0.0 and parameters: {'num_leaves ': 2.695695989187327, 'min_data_in_leaf': 37.924629016321546, 'max_depth': 8.740628970036408, 'bagging_fraction': 0.023631181441602766, 'bagging_freq': 2.7517568826563936, 'feature_fraction': 0.0770080221267695}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:17:02,576] Trial 183 finished with value: 0.0 and parameters: {'num_leaves ': 3.1748495197863384, 'min_data_in_leaf': 32.46696896268995, 'max_depth': 5.056597109999559, 'bagging_fraction': 0.009953625888862738, 'bagging_freq': 3.272599897177553, 'feature_fraction': 0.058466280041476686}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=32, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=32
# [LightGBM] [Warning] bagging_fraction is set=0.009953625888862738, subsample=1.0 will be ignored. Current value: bagging_fraction=0.009953625888862738
# [LightGBM] [Warning] feature_fraction is set=0.058466280041476686, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.058466280041476686
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] min_data_in_leaf is set=35, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=35
# [LightGBM] [Warning] bagging_fraction is set=0.1272229128430649, subsample=1.0 will be ignored. Current value: bagging_fraction=0.1272229128430649
# [LightGBM] [Warning] feature_fraction is set=0.050568854137114025, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.050568854137114025
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:02,891] Trial 184 finished with value: 0.0 and parameters: {'num_leaves ': 2.326714089544995, 'min_data_in_leaf': 35.24523223104457, 'max_depth': 5.194495782502853, 'bagging_fraction': 0.1272229128430649, 'bagging_freq': 1.40255165167381, 'feature_fraction': 0.050568854137114025}. Best is trial 0 with value: 0.0.
# [I 2021-06-23 15:17:03,037] Trial 185 finished with value: 0.0 and parameters: {'num_leaves ': 2.312437678228898, 'min_data_in_leaf': 43.36022083090943, 'max_depth': 7.1251903716351475, 'bagging_fraction': 0.027275073527994236, 'bagging_freq': 1.3365805035953475, 'feature_fraction': 0.0710314966150888}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=43, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=43
# [LightGBM] [Warning] bagging_fraction is set=0.027275073527994236, subsample=1.0 will be ignored. Current value: bagging_fraction=0.027275073527994236
# [LightGBM] [Warning] feature_fraction is set=0.0710314966150888, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0710314966150888
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=38, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=38
# [LightGBM] [Warning] bagging_fraction is set=0.04225527582668549, subsample=1.0 will be ignored. Current value: bagging_fraction=0.04225527582668549
# [LightGBM] [Warning] feature_fraction is set=0.04485794414849324, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.04485794414849324
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:03,197] Trial 186 finished with value: 0.0 and parameters: {'num_leaves ': 2.011379686862435, 'min_data_in_leaf': 38.827752263969295, 'max_depth': 4.744466246108896, 'bagging_fraction': 0.04225527582668549, 'bagging_freq': 1.424711338048989, 'feature_fraction': 0.04485794414849324}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=31, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=31
# [LightGBM] [Warning] bagging_fraction is set=0.19668742279628745, subsample=1.0 will be ignored. Current value: bagging_fraction=0.19668742279628745
# [LightGBM] [Warning] feature_fraction is set=0.03491998991409648, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03491998991409648
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:03,680] Trial 187 finished with value: 0.0 and parameters: {'num_leaves ': 39.047320321266405, 'min_data_in_leaf': 31.722577533082337, 'max_depth': 5.343482610678616, 'bagging_fraction': 0.19668742279628745, 'bagging_freq': 1.49199335544538, 'feature_fraction': 0.03491998991409648}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] bagging_fraction is set=0.14361668366898162, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14361668366898162
# [LightGBM] [Warning] feature_fraction is set=0.03715053269396592, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.03715053269396592
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:04,147] Trial 188 finished with value: 0.0 and parameters: {'num_leaves ': 36.845446839622916, 'min_data_in_leaf': 21.860055909565002, 'max_depth': 4.449506444520984, 'bagging_fraction': 0.14361668366898162, 'bagging_freq': 1.3101406113108263, 'feature_fraction': 0.03715053269396592}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=23, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=23
# [LightGBM] [Warning] bagging_fraction is set=0.19612303280778293, subsample=1.0 will be ignored. Current value: bagging_fraction=0.19612303280778293
# [LightGBM] [Warning] feature_fraction is set=0.08944039040557833, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.08944039040557833
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:04,822] Trial 189 finished with value: 0.0 and parameters: {'num_leaves ': 42.86116896857125, 'min_data_in_leaf': 23.256070239936314, 'max_depth': 4.621093226368577, 'bagging_fraction': 0.19612303280778293, 'bagging_freq': 1.4632346464008477, 'feature_fraction': 0.08944039040557833}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=26, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=26
# [LightGBM] [Warning] bagging_fraction is set=0.11411644527277504, subsample=1.0 will be ignored. Current value: bagging_fraction=0.11411644527277504
# [LightGBM] [Warning] feature_fraction is set=0.43876212774597917, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.43876212774597917
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [I 2021-06-23 15:17:05,362] Trial 190 finished with value: 0.0 and parameters: {'num_leaves ': 34.84398608944432, 'min_data_in_leaf': 26.240320859322466, 'max_depth': 4.106123510563355, 'bagging_fraction': 0.11411644527277504, 'bagging_freq': 2.658014152864509, 'feature_fraction': 0.43876212774597917}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=17, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=17
# [LightGBM] [Warning] bagging_fraction is set=0.04907418066961061, subsample=1.0 will be ignored. Current value: bagging_fraction=0.04907418066961061
# [LightGBM] [Warning] feature_fraction is set=0.390799098124509, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.390799098124509
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:05,789] Trial 191 finished with value: 0.0 and parameters: {'num_leaves ': 44.677838661792606, 'min_data_in_leaf': 17.0977246323423, 'max_depth': 5.5552876019416315, 'bagging_fraction': 0.04907418066961061, 'bagging_freq': 1.5898876514555507, 'feature_fraction': 0.390799098124509}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=35, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=35
# [LightGBM] [Warning] bagging_fraction is set=0.29432522764240804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.29432522764240804
# [LightGBM] [Warning] feature_fraction is set=0.7733389412479903, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7733389412479903
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:06,802] Trial 192 finished with value: 0.0 and parameters: {'num_leaves ': 30.79300363735253, 'min_data_in_leaf': 35.25735846502493, 'max_depth': 6.032014208643753, 'bagging_fraction': 0.29432522764240804, 'bagging_freq': 1.2471796408769902, 'feature_fraction': 0.7733389412479903}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=18, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=18
# [LightGBM] [Warning] bagging_fraction is set=0.2461060937057657, subsample=1.0 will be ignored. Current value: bagging_fraction=0.2461060937057657
# [LightGBM] [Warning] feature_fraction is set=0.06487568872760549, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.06487568872760549
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:07,443] Trial 193 finished with value: 0.0 and parameters: {'num_leaves ': 28.043036088927828, 'min_data_in_leaf': 18.648211028213517, 'max_depth': 6.894136175115668, 'bagging_fraction': 0.2461060937057657, 'bagging_freq': 1.6658917406209899, 'feature_fraction': 0.06487568872760549}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=19, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=19
# [LightGBM] [Warning] bagging_fraction is set=0.06455989725695516, subsample=1.0 will be ignored. Current value: bagging_fraction=0.06455989725695516
# [LightGBM] [Warning] feature_fraction is set=0.5165361382722279, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5165361382722279
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:07,897] Trial 194 finished with value: 0.0 and parameters: {'num_leaves ': 34.77013483151327, 'min_data_in_leaf': 19.787548613285306, 'max_depth': 3.801219354381597, 'bagging_fraction': 0.06455989725695516, 'bagging_freq': 1.7817266829736569, 'feature_fraction': 0.5165361382722279}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=21, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=21
# [LightGBM] [Warning] bagging_fraction is set=0.05801494614648433, subsample=1.0 will be ignored. Current value: bagging_fraction=0.05801494614648433
# [LightGBM] [Warning] feature_fraction is set=0.6142782394433209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6142782394433209
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:08,279] Trial 195 finished with value: 0.0 and parameters: {'num_leaves ': 31.08066552890117, 'min_data_in_leaf': 21.171977831946172, 'max_depth': 3.5625129290014175, 'bagging_fraction': 0.05801494614648433, 'bagging_freq': 1.6293954227462468, 'feature_fraction': 0.6142782394433209}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=16, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=16
# [LightGBM] [Warning] bagging_fraction is set=0.050720659340408446, subsample=1.0 will be ignored. Current value: bagging_fraction=0.050720659340408446
# [LightGBM] [Warning] feature_fraction is set=0.8903581405590231, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8903581405590231
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:08,736] Trial 196 finished with value: 0.0 and parameters: {'num_leaves ': 38.33870299938777, 'min_data_in_leaf': 16.12002211419499, 'max_depth': 6.240985290563331, 'bagging_fraction': 0.050720659340408446, 'bagging_freq': 1.8157453184726207, 'feature_fraction': 0.8903581405590231}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=24, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=24
# [LightGBM] [Warning] bagging_fraction is set=0.14687319221401726, subsample=1.0 will be ignored. Current value: bagging_fraction=0.14687319221401726
# [LightGBM] [Warning] feature_fraction is set=0.0985621075344931, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.0985621075344931
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:09,241] Trial 197 finished with value: 0.0 and parameters: {'num_leaves ': 42.0154750980157, 'min_data_in_leaf': 24.85507935856012, 'max_depth': 3.3538876602006633, 'bagging_fraction': 0.14687319221401726, 'bagging_freq': 1.6820947773641648, 'feature_fraction': 0.0985621075344931}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=28, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=28
# [LightGBM] [Warning] bagging_fraction is set=0.08595108887589623, subsample=1.0 will be ignored. Current value: bagging_fraction=0.08595108887589623
# [LightGBM] [Warning] feature_fraction is set=0.4640450343114621, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.4640450343114621
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:09,691] Trial 198 finished with value: 0.0 and parameters: {'num_leaves ': 33.20851662669952, 'min_data_in_leaf': 28.488062948345014, 'max_depth': 5.761299294726117, 'bagging_fraction': 0.08595108887589623, 'bagging_freq': 1.4876004276492851, 'feature_fraction': 0.4640450343114621}. Best is trial 0 with value: 0.0.
# [LightGBM] [Warning] min_data_in_leaf is set=29, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=29
# [LightGBM] [Warning] bagging_fraction is set=0.39351413102072, subsample=1.0 will be ignored. Current value: bagging_fraction=0.39351413102072
# [LightGBM] [Warning] feature_fraction is set=0.6347341988385513, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6347341988385513
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [I 2021-06-23 15:17:10,603] Trial 199 finished with value: 0.0 and parameters: {'num_leaves ': 29.771271201590075, 'min_data_in_leaf': 29.830829600864387, 'max_depth': 5.083877489483183, 'bagging_fraction': 0.39351413102072, 'bagging_freq': 1.5812606893652013, 'feature_fraction': 0.6347341988385513}. Best is trial 0 with value: 0.0.

# %%
# 最適なハイパーパラメータとその検証用データセットでの正答率
study.best_params, 1.0 - study.best_value
# Out:
# ({'num_leaves ': 11.070313153975668,
#   'min_data_in_leaf': 54.438228867000234,
#   'max_depth': 1.9106163322573242,
#   'bagging_fraction': 0.011186138854175218,
#   'bagging_freq': 1.1600243875309322,
#   'feature_fraction': 0.14167845037624854},
#  1.0)

# %%
# 勾配ブースティング決定木回帰モデルの学習
from lightgbm import LGBMClassifier
nbr = LGBMClassifier(
                    learning_rate = 0.01,
                    n_estimators = 1000,
                    num_leaves = 9,
                    min_data_in_leaf = 38,
                    max_depth = 7,
                    bagging_fraction = 0.288,
                    bagging_freq = 1,
                    feature_fraction = 0.785
)
nbr.fit(X_train, y_train,
        eval_set = (X_train, y_train), 
        early_stopping_rounds = 5, 
        verbose = 500)     # verboseは学習の様子をprintするiterationの間隔
# Out:
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_data_in_leaf is set=38, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=38
# [LightGBM] [Warning] feature_fraction is set=0.785, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.785
# [LightGBM] [Warning] bagging_fraction is set=0.288, subsample=1.0 will be ignored. Current value: bagging_fraction=0.288
# Training until validation scores don't improve for 5 rounds
# [500]	training's multi_logloss: 0.290904
# [1000]	training's multi_logloss: 0.242414
# Did not meet early stopping. Best iteration is:
# [1000]	training's multi_logloss: 0.242414
# LGBMClassifier(bagging_fraction=0.288, bagging_freq=1, feature_fraction=0.785,
#                learning_rate=0.01, max_depth=7, min_data_in_leaf=38,
#                n_estimators=1000, num_leaves=9)

# %%
from sklearn.metrics import f1_score

f1_train = f1_score(y_train, nbr.predict(X_train), average='macro')
f1_test = f1_score(y_test, nbr.predict(X_test), average='macro')

# 評価結果の表示
print("f1_train:", f1_train, "f1_test", f1_test)
# Out:
# f1_train: 0.8191378350873633 f1_test 0.7013205989859687

# %%
import numpy as np
# 変数重要度（入力変数ごとに決定木回帰の変数重要度の平均を取ったもの）
importances = nbr.booster_.feature_importance(importance_type = "gain")
indices = np.argsort(importances)[30:]
plt.barh(np.asarray(feature_name)[indices], importances[indices],
         color="r", align="center")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

cm_train = confusion_matrix(y_train, nbr.predict(X_train))
cm_test = confusion_matrix(y_test, nbr.predict(X_test))

# 混同行列の表示
print(cm_train)
print(cm_test)
# Out:
# [[967  30   8]
#  [ 56  91  11]
#  [  8   5 104]]
# [[244   4   3]
#  [ 18  15   7]
#  [  1   7  21]]

# %% [markdown]
# ## oputuna拡張機能(LightGBM Tuner)

# %%
# 勾配ブースティング決定木回帰モデルの学習
from lightgbm import LGBMClassifier
import optuna.integration.lightgbm as lgb_tune

X = X[['bmi', 'age', 'smoker_yes', 'smoker_age_mean', 'gen_sex_bmi_mean']]

x_train, x_val, y_train, y_val =train_test_split(X, y, test_size=0.2)

param = {
        'objective': 'multiclass',
        'metric': 'multi_logloss',
        'num_class': 3,
        'verbosity': -1,
        'boosting_type': 'gbdt',
    }

dtrain = lgb_tune.Dataset(x_train, label=y_train)
eval_data = lgb_tune.Dataset(x_val, label=y_val)


best = lgb_tune.train(param, dtrain,
                      valid_sets=eval_data,
                      early_stopping_rounds=100)
# Out:
# [I 2021-06-24 10:11:41,260] A new study created in memory with name: no-name-e7cb3f5c-585b-47de-b9d9-d40c73e22728
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
# feature_fraction, val_score: inf:   0%|          | 0/7 [00:00<?, ?it/s]
# [1]	valid_0's multi_logloss: 0.588733
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0
# [77]	valid_0's multi_logloss: 0.464139
# [78]	valid_0's multi_logloss: 0.465531
# [79]	valid_0's multi_logloss: 0.465933
# [80]	valid_0's multi_logloss: 0.468094
# [81]	valid_0's multi_logloss: 0.471161
# [82]	valid_0's multi_logloss: 0.473241
# [83]	valid_0's multi_logloss: 0.474702
# [84]	valid_0's multi_logloss: 0.47619
# [85]	valid_0's multi_logloss: 0.476185
# [86]	valid_0's multi_logloss: 0.477374
# [87]	valid_0's multi_logloss: 0.47788
# [88]	valid_0's multi_logloss: 0.480722
# [89]	valid_0's multi_logloss: 0.482405
# [90]	valid_0's multi_logloss: 0.484763
# [91]	valid_0's multi_logloss: 0.485508
# [92]	valid_0's multi_logloss: 0.487086
# [93]	valid_0's multi_logloss: 0.490402
# [94]	valid_0's multi_logloss: 0.492379
# [95]	valid_0's multi_logloss: 0.493505
# feature_fraction, val_score: 0.407767:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
# feature_fraction, val_score: 0.407767:  14%|#4        | 1/7 [00:00<00:01,  3.23it/s][I 2021-06-24 10:11:41,576] Trial 0 finished with value: 0.40776688866249156 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.40776688866249156.
#
#
#
# feature_fraction, val_score: 0.407767:  14%|#4        | 1/7 [00:00<00:01,  3.23it/s]
# [96]	valid_0's multi_logloss: 0.494792
# [97]	valid_0's multi_logloss: 0.49672
# [98]	valid_0's multi_logloss: 0.498511
# [99]	valid_0's multi_logloss: 0.499275
# [100]	valid_0's multi_logloss: 0.501349
# [101]	valid_0's multi_logloss: 0.503504
# [102]	valid_0's multi_logloss: 0.506047
# [103]	valid_0's multi_logloss: 0.507161
# [104]	valid_0's multi_logloss: 0.510022
# [105]	valid_0's multi_logloss: 0.511573
# [106]	valid_0's multi_logloss: 0.512408
# [107]	valid_0's multi_logloss: 0.513723
# [108]	valid_0's multi_logloss: 0.51549
# [109]	valid_0's multi_logloss: 0.51612
# [110]	valid_0's multi_logloss: 0.517486
# [111]	valid_0's multi_logloss: 0.518987
# [112]	valid_0's multi_logloss: 0.520431
# [113]	valid_0's multi_logloss: 0.522061
# [114]	valid_0's multi_logloss: 0.523432
# [115]	valid_0's multi_logloss: 0.524236
# [116]	valid_0's multi_logloss: 0.526651
# [117]	valid_0's multi_logloss: 0.527925
# [118]	valid_0's multi_logloss: 0.529734
# [119]	valid_0's multi_logloss: 0.530556
# [120]	valid_0's multi_logloss: 0.532542
# [121]	valid_0's multi_logloss: 0.533043
# [122]	valid_0's multi_logloss: 0.534834
# [123]	valid_0's multi_logloss: 0.53682
# [124]	valid_0's multi_logloss: 0.53882
# Early stopping, best iteration is:
# [24]	valid_0's multi_logloss: 0.407767
# [1]	valid_0's multi_logloss: 0.562319
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.517543
# [3]	valid_0's multi_logloss: 0.486355
# [4]	valid_0's multi_logloss: 0.462616
# [5]	valid_0's multi_logloss: 0.444603
# [6]	valid_0's multi_logloss: 0.429335
# [7]	valid_0's multi_logloss: 0.417519
# [8]	valid_0's multi_logloss: 0.409471
# [9]	valid_0's multi_logloss: 0.403508
# [10]	valid_0's multi_logloss: 0.398805
# [11]	valid_0's multi_logloss: 0.395302
# [12]	valid_0's multi_logloss: 0.390893
# [13]	valid_0's multi_logloss: 0.388045
# [14]	valid_0's multi_logloss: 0.385427
# [15]	valid_0's multi_logloss: 0.385842
# [16]	valid_0's multi_logloss: 0.386604
# [17]	valid_0's multi_logloss: 0.38801
# [18]	valid_0's multi_logloss: 0.390436
# [19]	valid_0's multi_logloss: 0.39127
# [20]	valid_0's multi_logloss: 0.39319
# [21]	valid_0's multi_logloss: 0.394752
# [22]	valid_0's multi_logloss: 0.398756
# [23]	valid_0's multi_logloss: 0.401104
# [24]	valid_0's multi_logloss: 0.403899
# [25]	valid_0's multi_logloss: 0.406024
# [26]	valid_0's multi_logloss: 0.408113
# [27]	valid_0's multi_logloss: 0.411094
# [28]	valid_0's multi_logloss: 0.413583
# [29]	valid_0's multi_logloss: 0.415199
# [30]	valid_0's multi_logloss: 0.416671
# [31]	valid_0's multi_logloss: 0.417799
# [32]	valid_0's multi_logloss: 0.419876
# [33]	valid_0's multi_logloss: 0.420595
# [34]	valid_0's multi_logloss: 0.420786
# [35]	valid_0's multi_logloss: 0.422053
# [36]	valid_0's multi_logloss: 0.423267
# [37]	valid_0's multi_logloss: 0.425028
# [38]	valid_0's multi_logloss: 0.427648
# [39]	valid_0's multi_logloss: 0.429168
# [40]	valid_0's multi_logloss: 0.431284
# [41]	valid_0's multi_logloss: 0.432987
# [42]	valid_0's multi_logloss: 0.434844
# [43]	valid_0's multi_logloss: 0.436705
# [44]	valid_0's multi_logloss: 0.438442
# feature_fraction, val_score: 0.385427:  14%|#4        | 1/7 [00:00<00:01,  3.23it/s]
#
#
# feature_fraction, val_score: 0.385427:  29%|##8       | 2/7 [00:00<00:01,  3.15it/s]
# [45]	valid_0's multi_logloss: 0.441708
# [46]	valid_0's multi_logloss: 0.444037
# [47]	valid_0's multi_logloss: 0.444421
# [48]	valid_0's multi_logloss: 0.445238
# [49]	valid_0's multi_logloss: 0.448267
# [50]	valid_0's multi_logloss: 0.450186
# [51]	valid_0's multi_logloss: 0.453
# [52]	valid_0's multi_logloss: 0.455688
# [53]	valid_0's multi_logloss: 0.457293
# [54]	valid_0's multi_logloss: 0.459379
# [55]	valid_0's multi_logloss: 0.462136
# [56]	valid_0's multi_logloss: 0.46478
# [57]	valid_0's multi_logloss: 0.466677
# [58]	valid_0's multi_logloss: 0.469553
# [59]	valid_0's multi_logloss: 0.471071
# [60]	valid_0's multi_logloss: 0.473182
# [61]	valid_0's multi_logloss: 0.476034
# [62]	valid_0's multi_logloss: 0.478499
# [63]	valid_0's multi_logloss: 0.479415
# [64]	valid_0's multi_logloss: 0.483829
# [65]	valid_0's multi_logloss: 0.485623
# [66]	valid_0's multi_logloss: 0.488064
# [67]	valid_0's multi_logloss: 0.491092
# [68]	valid_0's multi_logloss: 0.49332
# [69]	valid_0's multi_logloss: 0.495862
# [70]	valid_0's multi_logloss: 0.498301
# [71]	valid_0's multi_logloss: 0.499785
# [72]	valid_0's multi_logloss: 0.503523
and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 0.3854266748768856.
#
#
#
# feature_fraction, val_score: 0.385427:  43%|####2     | 3/7 [00:00<00:01,  3.18it/s]
# [80]	valid_0's multi_logloss: 0.494876
# [81]	valid_0's multi_logloss: 0.497556
# [82]	valid_0's multi_logloss: 0.500531
# [83]	valid_0's multi_logloss: 0.502455
# [84]	valid_0's multi_logloss: 0.503798
# [85]	valid_0's multi_logloss: 0.505912
# [86]	valid_0's multi_logloss: 0.508825
# [87]	valid_0's multi_logloss: 0.511118
# [88]	valid_0's multi_logloss: 0.513828
# [89]	valid_0's multi_logloss: 0.516431
# [90]	valid_0's multi_logloss: 0.516702
# [91]	valid_0's multi_logloss: 0.518591
# [92]	valid_0's multi_logloss: 0.520305
# [93]	valid_0's multi_logloss: 0.522798
# [94]	valid_0's multi_logloss: 0.522812
# [95]	valid_0's multi_logloss: 0.526179
# [96]	valid_0's multi_logloss: 0.527166
# [97]	valid_0's multi_logloss: 0.529332
# [98]	valid_0's multi_logloss: 0.531644
# [99]	valid_0's multi_logloss: 0.534157
# [100]	valid_0's multi_logloss: 0.536069
# [101]	valid_0's multi_logloss: 0.539004
# [102]	valid_0's multi_logloss: 0.540924
# [103]	valid_0's multi_logloss: 0.543786
# [104]	valid_0's multi_logloss: 0.544025
# [105]	valid_0's multi_logloss: 0.546584
# [106]	valid_0's multi_logloss: 0.548173
# [107]	valid_0's multi_logloss: 0.550365
# [108]	valid_0's multi_logloss: 0.550651
# [109]	valid_0's multi_logloss: 0.552576
# [110]	valid_0's multi_logloss: 0.554525
# [111]	valid_0's multi_logloss: 0.556665
# [112]	valid_0's multi_logloss: 0.55802
# [113]	valid_0's multi_logloss: 0.560005
# [114]	valid_0's multi_logloss: 0.561248
# [115]	valid_0's multi_logloss: 0.563555
# [116]	valid_0's multi_logloss: 0.56449
# [117]	valid_0's multi_logloss: 0.566241
# [118]	valid_0's multi_logloss: 0.567096
# [119]	valid_0's multi_logloss: 0.568808
# [120]	valid_0's multi_logloss: 0.57023
# [121]	valid_0's multi_logloss: 0.57259
# [122]	valid_0's multi_logloss: 0.573558
# [123]	valid_0's multi_logloss: 0.576506
# [124]	valid_0's multi_logloss: 0.57805
# [125]	valid_0's multi_logloss: 0.579348
# Early stopping, best iteration is:
# [25]	valid_0's multi_logloss: 0.38804
# [1]	valid_0's multi_logloss: 0.571926
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.527753
# [3]	valid_0's multi_logloss: 0.498324
# [4]	valid_0's multi_logloss: 0.47585
# [5]	valid_0's multi_logloss: 0.458398
# [6]	valid_0's multi_logloss: 0.441374
# [7]	valid_0's multi_logloss: 0.427321
# [8]	valid_0's multi_logloss: 0.417315
# [9]	valid_0's multi_logloss: 0.408441
# [10]	valid_0's multi_logloss: 0.401001
# [11]	valid_0's multi_logloss: 0.394676
# [12]	valid_0's multi_logloss: 0.39199
# [13]	valid_0's multi_logloss: 0.387887
# [14]	valid_0's multi_logloss: 0.38649
# [15]	valid_0's multi_logloss: 0.385724
# [16]	valid_0's multi_logloss: 0.385098
# [17]	valid_0's multi_logloss: 0.38529
# [18]	valid_0's multi_logloss: 0.383912
# [19]	valid_0's multi_logloss: 0.384296
# [20]	valid_0's multi_logloss: 0.386439
# [21]	valid_0's multi_logloss: 0.38612
# [89]	valid_0's multi_logloss: 0.519057
# [90]	valid_0's multi_logloss: 0.520995
# [91]	valid_0's multi_logloss: 0.522528
# [92]	valid_0's multi_logloss: 0.523763
# [93]	valid_0's multi_logloss: 0.525642
# [94]	valid_0's multi_logloss: 0.527676
# [95]	valid_0's multi_logloss: 0.531049
# [96]	valid_0's multi_logloss: 0.532616
# [97]	valid_0's multi_logloss: 0.534235
# [98]	valid_0's multi_logloss: 0.537644
# [99]	valid_0's multi_logloss: 0.539582
# [100]	valid_0's multi_logloss: 0.54148
# [101]	valid_0's multi_logloss: 0.544969
# [102]	valid_0's multi_logloss: 0.546776
# [103]	valid_0's multi_logloss: 0.549402
# [104]	valid_0's multi_logloss: 0.552469
# [105]	valid_0's multi_logloss: 0.553541
# [106]	valid_0's multi_logloss: 0.5555
# feature_fraction, val_score: 0.383912:  43%|####2     | 3/7 [00:01<00:01,  3.18it/s]
#
#
# feature_fraction, val_score: 0.383912:  57%|#####7    | 4/7 [00:01<00:01,  2.96it/s][I 2021-06-24 10:11:42,583] Trial 3 finished with value: 0.3839121467956449 and parameters: {'feature_fraction': 0.8}. Best is trial 3 with value: 0.3839121467956449.
#
#
#
# feature_fraction, val_score: 0.383912:  57%|#####7    | 4/7 [00:01<00:01,  2.96it/s]
# [107]	valid_0's multi_logloss: 0.558427
# [108]	valid_0's multi_logloss: 0.56145
# [109]	valid_0's multi_logloss: 0.564715
# [110]	valid_0's multi_logloss: 0.566337
# [111]	valid_0's multi_logloss: 0.567907
# [112]	valid_0's multi_logloss: 0.570158
# [113]	valid_0's multi_logloss: 0.57201
# [114]	valid_0's multi_logloss: 0.573651
# [115]	valid_0's multi_logloss: 0.57589
# [116]	valid_0's multi_logloss: 0.578356
# [117]	valid_0's multi_logloss: 0.58079
# [118]	valid_0's multi_logloss: 0.581969
# Early stopping, best iteration is:
# [18]	valid_0's multi_logloss: 0.383912
# [1]	valid_0's multi_logloss: 0.571926
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.527753
# [3]	valid_0's multi_logloss: 0.498324
# [4]	valid_0's multi_logloss: 0.47585
# [5]	valid_0's multi_logloss: 0.458398
# [6]	valid_0's multi_logloss: 0.441374
# [7]	valid_0's multi_logloss: 0.427321
# [8]	valid_0's multi_logloss: 0.417315
# [9]	valid_0's multi_logloss: 0.408441
# [10]	valid_0's multi_logloss: 0.401001
# [11]	valid_0's multi_logloss: 0.394676
# [12]	valid_0's multi_logloss: 0.39199
# [13]	valid_0's multi_logloss: 0.387887
# [14]	valid_0's multi_logloss: 0.38649
# [15]	valid_0's multi_logloss: 0.385724
# [16]	valid_0's multi_logloss: 0.385098
# [17]	valid_0's multi_logloss: 0.38529
# [18]	valid_0's multi_logloss: 0.383912
# [19]	valid_0's multi_logloss: 0.384296
# [20]	valid_0's multi_logloss: 0.386439
# [21]	valid_0's multi_logloss: 0.38612
# [22]	valid_0's multi_logloss: 0.38842
# [23]	valid_0's multi_logloss: 0.389013
# [24]	valid_0's multi_logloss: 0.389211
# [25]	valid_0's multi_logloss: 0.390737
# [26]	valid_0's multi_logloss: 0.392464
# [27]	valid_0's multi_logloss: 0.394634
# [28]	valid_0's multi_logloss: 0.398351
# [29]	valid_0's multi_logloss: 0.400154
# [30]	valid_0's multi_logloss: 0.402179
# [31]	valid_0's multi_logloss: 0.40473
# [32]	valid_0's multi_logloss: 0.407039
# [33]	valid_0's multi_logloss: 0.41036
# [34]	valid_0's multi_logloss: 0.413226
# [35]	valid_0's multi_logloss: 0.414824
# [36]	valid_0's multi_logloss: 0.416928
# [37]	valid_0's multi_logloss: 0.41898
# [38]	valid_0's multi_logloss: 0.422356
# [39]	valid_0's multi_logloss: 0.424454
# [40]	valid_0's multi_logloss: 0.426179
# [41]	valid_0's multi_logloss: 0.427325
# [42]	valid_0's multi_logloss: 0.42966
# [43]	valid_0's multi_logloss: 0.432608
# [44]	valid_0's multi_logloss: 0.432805
# [45]	valid_0's multi_logloss: 0.434447
# [46]	valid_0's multi_logloss: 0.436968
# [47]	valid_0's multi_logloss: 0.438899
# [48]	valid_0's multi_logloss: 0.441481
# [49]	valid_0's multi_logloss: 0.443197
# [50]	valid_0's multi_logloss: 0.44503
# [51]	valid_0's multi_logloss: 0.449648
# [52]	valid_0's multi_logloss: 0.450167
# [53]	valid_0's multi_logloss: 0.451372
# [54]	valid_0's multi_logloss: 0.452865
# [55]	valid_0's multi_logloss: 0.45328
# [56]	valid_0's multi_logloss: 0.456725
# [57]	valid_0's multi_logloss: 0.459623
# [58]	valid_0's multi_logloss: 0.460147
# [59]	valid_0's multi_logloss: 0.462053
# [60]	valid_0's multi_logloss: 0.463758
# [61]	valid_0's multi_logloss: 0.46386
# [62]	valid_0's multi_logloss: 0.466442
# [63]	valid_0's multi_logloss: 0.467756
# [64]	valid_0's multi_logloss: 0.468534
# [65]	valid_0's multi_logloss: 0.470855
# [66]	valid_0's multi_logloss: 0.472925
# [67]	valid_0's multi_logloss: 0.473548
# [68]	valid_0's multi_logloss: 0.475266
# [69]	valid_0's multi_logloss: 0.478929
# [70]	valid_0's multi_logloss: 0.480578
# [71]	valid_0's multi_logloss: 0.483289
# [72]	valid_0's multi_logloss: 0.484529
# [73]	valid_0's multi_logloss: 0.486583
# feature_fraction, val_score: 0.383912:  57%|#####7    | 4/7 [00:01<00:01,  2.96it/s]
#
#
# feature_fraction, val_score: 0.383912:  71%|#######1  | 5/7 [00:01<00:00,  3.03it/s][I 2021-06-24 10:11:42,900] Trial 4 finished with value: 0.3839121467956449 and parameters: {'feature_fraction': 0.7}. Best is trial 3 with value: 0.3839121467956449.
#
#
#
# feature_fraction, val_score: 0.383912:  71%|#######1  | 5/7 [00:01<00:00,  3.03it/s]
# [74]	valid_0's multi_logloss: 0.487814
# [75]	valid_0's multi_logloss: 0.490376
# [76]	valid_0's multi_logloss: 0.49203
# [77]	valid_0's multi_logloss: 0.494808
# [78]	valid_0's multi_logloss: 0.497837
# [79]	valid_0's multi_logloss: 0.500001
# [80]	valid_0's multi_logloss: 0.501346
# [81]	valid_0's multi_logloss: 0.502518
# [82]	valid_0's multi_logloss: 0.504952
# [31]	valid_0's multi_logloss: 0.417799
# [32]	valid_0's multi_logloss: 0.419876
# [33]	valid_0's multi_logloss: 0.420595
# [34]	valid_0's multi_logloss: 0.420786
# [35]	valid_0's multi_logloss: 0.422053
# [36]	valid_0's multi_logloss: 0.423267
# [37]	valid_0's multi_logloss: 0.425028
# [38]	valid_0's multi_logloss: 0.427648
# [39]	valid_0's multi_logloss: 0.429168
# [40]	valid_0's multi_logloss: 0.431284
# [41]	valid_0's multi_logloss: 0.432987
# [42]	valid_0's multi_logloss: 0.434844
# [43]	valid_0's multi_logloss: 0.436705
# [44]	valid_0's multi_logloss: 0.438442
# [45]	valid_0's multi_logloss: 0.441708
# [46]	valid_0's multi_logloss: 0.444037
# [47]	valid_0's multi_logloss: 0.444421
# [48]	valid_0's multi_logloss: 0.445238
# [49]	valid_0's multi_logloss: 0.448267
# [50]	valid_0's multi_logloss: 0.450186
# [51]	valid_0's multi_logloss: 0.453
# [52]	valid_0's multi_logloss: 0.455688
# [53]	valid_0's multi_logloss: 0.457293
# [54]	valid_0's multi_logloss: 0.459379
# [55]	valid_0's multi_logloss: 0.462136
# [56]	valid_0's multi_logloss: 0.46478
# [57]	valid_0's multi_logloss: 0.466677
# [58]	valid_0's multi_logloss: 0.469553
# [59]	valid_0's multi_logloss: 0.471071
# [60]	valid_0's multi_logloss: 0.473182
# [61]	valid_0's multi_logloss: 0.476034
# [62]	valid_0's multi_logloss: 0.478499
# [63]	valid_0's multi_logloss: 0.479415
# [64]	valid_0's multi_logloss: 0.483829
# [65]	valid_0's multi_logloss: 0.485623
# [66]	valid_0's multi_logloss: 0.488064
# [67]	valid_0's multi_logloss: 0.491092
# [68]	valid_0's multi_logloss: 0.49332
# [69]	valid_0's multi_logloss: 0.495862
# [70]	valid_0's multi_logloss: 0.498301
# [71]	valid_0's multi_logloss: 0.499785
# [72]	valid_0's multi_logloss: 0.503523
# [73]	valid_0's multi_logloss: 0.505903
# [74]	valid_0's multi_logloss: 0.508031
# [75]	valid_0's multi_logloss: 0.509395
# [76]	valid_0's multi_logloss: 0.512739
# [77]	valid_0's multi_logloss: 0.515488
# [78]	valid_0's multi_logloss: 0.518143
# [79]	valid_0's multi_logloss: 0.521897
# [80]	valid_0's multi_logloss: 0.524529
# [81]	valid_0's multi_logloss: 0.52694
# [82]	valid_0's multi_logloss: 0.529864
# [83]	valid_0's multi_logloss: 0.531439
# [84]	valid_0's multi_logloss: 0.533886
# [85]	valid_0's multi_logloss: 0.536747
# [86]	valid_0's multi_logloss: 0.536982
# [87]	valid_0's multi_logloss: 0.539189
# [88]	valid_0's multi_logloss: 0.542025
# [89]	valid_0's multi_logloss: 0.543972
# [90]	valid_0's multi_logloss: 0.546483
# [91]	valid_0's multi_logloss: 0.547627
# [92]	valid_0's multi_logloss: 0.5504
# [93]	valid_0's multi_logloss: 0.553292
# feature_fraction, val_score: 0.383912:  71%|#######1  | 5/7 [00:01<00:00,  3.03it/s]
#
#
# feature_fraction, val_score: 0.383912:  86%|########5 | 6/7 [00:01<00:00,  3.10it/s][I 2021-06-24 10:11:43,208] Trial 5 finished with value: 0.3854266748768856 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 3 with value: 0.3839121467956449.
#
#
#
# feature_fraction, val_score: 0.383912:  86%|########5 | 6/7 [00:01<00:00,  3.10it/s]
# [94]	valid_0's multi_logloss: 0.554674
# [95]	valid_0's multi_logloss: 0.556828
# [96]	valid_0's multi_logloss: 0.559132
# [97]	valid_0's multi_logloss: 0.561622
# [98]	valid_0's multi_logloss: 0.565214
# [99]	valid_0's multi_logloss: 0.566584
# [100]	valid_0's multi_logloss: 0.56884
# [101]	valid_0's multi_logloss: 0.570328
# [102]	valid_0's multi_logloss: 0.574786
# [103]	valid_0's multi_logloss: 0.577838
# [104]	valid_0's multi_logloss: 0.579159
# [105]	valid_0's multi_logloss: 0.580504
# [106]	valid_0's multi_logloss: 0.582606
# [107]	valid_0's multi_logloss: 0.58436
# [108]	valid_0's multi_logloss: 0.58645
# [109]	valid_0's multi_logloss: 0.588457
# [110]	valid_0's multi_logloss: 0.589772
# [111]	valid_0's multi_logloss: 0.593369
# [112]	valid_0's multi_logloss: 0.594478
# [113]	valid_0's multi_logloss: 0.597335
# [114]	valid_0's multi_logloss: 0.600126
# Early stopping, best iteration is:
# [14]	valid_0's multi_logloss: 0.385427
# [1]	valid_0's multi_logloss: 0.59908
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.559398
# [3]	valid_0's multi_logloss: 0.533024
# [4]	valid_0's multi_logloss: 0.503524
# [5]	valid_0's multi_logloss: 0.482373
# [6]	valid_0's multi_logloss: 0.470598
# [7]	valid_0's multi_logloss: 0.452956
# [8]	valid_0's multi_logloss: 0.438958
# [9]	valid_0's multi_logloss: 0.429182
# [10]	valid_0's multi_logloss: 0.420358
# [11]	valid_0's multi_logloss: 0.413573
# [12]	valid_0's multi_logloss: 0.407167
# [13]	valid_0's multi_logloss: 0.402191
# [14]	valid_0's multi_logloss: 0.398372
# [15]	valid_0's multi_logloss: 0.396021
# [16]	valid_0's multi_logloss: 0.39241
# [17]	valid_0's multi_logloss: 0.390669
# [18]	valid_0's multi_logloss: 0.389914
# [19]	valid_0's multi_logloss: 0.388192
# [20]	valid_0's multi_logloss: 0.389207
# [21]	valid_0's multi_logloss: 0.389193
# [22]	valid_0's multi_logloss: 0.388099
# [23]	valid_0's multi_logloss: 0.3891
# [24]	valid_0's multi_logloss: 0.388331
# [25]	valid_0's multi_logloss: 0.38804
# [26]	valid_0's multi_logloss: 0.390653
# [27]	valid_0's multi_logloss: 0.3906
# [28]	valid_0's multi_logloss: 0.391117
# [29]	valid_0's multi_logloss: 0.392154
# [30]	valid_0's multi_logloss: 0.39326
# [31]	valid_0's multi_logloss: 0.393532
# [32]	valid_0's multi_logloss: 0.394234
# [33]	valid_0's multi_logloss: 0.397271
# [34]	valid_0's multi_logloss: 0.397715
# [35]	valid_0's multi_logloss: 0.398773
# [36]	valid_0's multi_logloss: 0.402488
# [37]	valid_0's multi_logloss: 0.405116
# [38]	valid_0's multi_logloss: 0.406216
# [39]	valid_0's multi_logloss: 0.408748
# [40]	valid_0's multi_logloss: 0.409275
# feature_fraction, val_score: 0.383912:  86%|########5 | 6/7 [00:02<00:00,  3.10it/s]
#
#
# feature_fraction, val_score: 0.383912: 100%|##########| 7/7 [00:02<00:00,  3.12it/s][I 2021-06-24 10:11:43,525] Trial 6 finished with value: 0.38803959593026854 and parameters: {'feature_fraction': 0.5}. Best is trial 3 with value: 0.3839121467956449.
# feature_fraction, val_score: 0.383912: 100%|##########| 7/7 [00:02<00:00,  3.10it/s]
#
#
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#
#
# [106]	valid_0's multi_logloss: 0.61862
# [107]	valid_0's multi_logloss: 0.622354
# [108]	valid_0's multi_logloss: 0.623829
# num_leaves, val_score: 0.383912:   0%|          | 0/20 [00:00<?, ?it/s]
#
#
# num_leaves, val_score: 0.383912:   5%|5         | 1/20 [00:00<00:09,  1.99it/s][I 2021-06-24 10:11:44,030] Trial 7 finished with value: 0.38580529610470193 and parameters: {'num_leaves': 147}. Best is trial 7 with value: 0.38580529610470193.
#
#
#
# num_leaves, val_score: 0.383912:   5%|5         | 1/20 [00:00<00:09,  1.99it/s]
# [109]	valid_0's multi_logloss: 0.625211
# [110]	valid_0's multi_logloss: 0.628758
# [111]	valid_0's multi_logloss: 0.631613
# [112]	valid_0's multi_logloss: 0.634105
# [113]	valid_0's multi_logloss: 0.637251
# [114]	valid_0's multi_logloss: 0.641016
# [115]	valid_0's multi_logloss: 0.64346
# [116]	valid_0's multi_logloss: 0.647092
# [117]	valid_0's multi_logloss: 0.648976
# [118]	valid_0's multi_logloss: 0.652643
# Early stopping, best iteration is:
# [18]	valid_0's multi_logloss: 0.385805
# [1]	valid_0's multi_logloss: 0.572049
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.527924
# [3]	valid_0's multi_logloss: 0.498341
# [4]	valid_0's multi_logloss: 0.475768
# [5]	valid_0's multi_logloss: 0.458229
# [6]	valid_0's multi_logloss: 0.441971
# [7]	valid_0's multi_logloss: 0.428234
# [8]	valid_0's multi_logloss: 0.418872
# [9]	valid_0's multi_logloss: 0.410161
# [10]	valid_0's multi_logloss: 0.403175
# [11]	valid_0's multi_logloss: 0.39672
# [12]	valid_0's multi_logloss: 0.393408
# [13]	valid_0's multi_logloss: 0.389796
# [14]	valid_0's multi_logloss: 0.388304
# [15]	valid_0's multi_logloss: 0.38829
# [16]	valid_0's multi_logloss: 0.386802
# [17]	valid_0's multi_logloss: 0.387421
# [18]	valid_0's multi_logloss: 0.385806
# [19]	valid_0's multi_logloss: 0.385805
# [20]	valid_0's multi_logloss: 0.388209
# [21]	valid_0's multi_logloss: 0.388415
# [22]	valid_0's multi_logloss: 0.390989
# [23]	valid_0's multi_logloss: 0.391683
# [24]	valid_0's multi_logloss: 0.391797
# [25]	valid_0's multi_logloss: 0.394477
# [26]	valid_0's multi_logloss: 0.395936
# [27]	valid_0's multi_logloss: 0.397839
# [28]	valid_0's multi_logloss: 0.401234
# [29]	valid_0's multi_logloss: 0.404734
# [30]	valid_0's multi_logloss: 0.40685
# [31]	valid_0's multi_logloss: 0.409965
# [32]	valid_0's multi_logloss: 0.412628
# [33]	valid_0's multi_logloss: 0.414418
# [34]	valid_0's multi_logloss: 0.420715
# [35]	valid_0's multi_logloss: 0.422029
# [36]	valid_0's multi_logloss: 0.424941
# [37]	valid_0's multi_logloss: 0.428592
# [38]	valid_0's multi_logloss: 0.431177
# [39]	valid_0's multi_logloss: 0.433881
# [40]	valid_0's multi_logloss: 0.435648
# [41]	valid_0's multi_logloss: 0.438934
# [42]	valid_0's multi_logloss: 0.442741
# [43]	valid_0's multi_logloss: 0.445144
# [44]	valid_0's multi_logloss: 0.447389
# [112]	valid_0's multi_logloss: 0.641931
# [113]	valid_0's multi_logloss: 0.645
# [114]	valid_0's multi_logloss: 0.648255
# [115]	valid_0's multi_logloss: 0.651259
# num_leaves, val_score: 0.383912:   5%|5         | 1/20 [00:01<00:09,  1.99it/s]
#
#
# num_leaves, val_score: 0.383912:  10%|#         | 2/20 [00:01<00:15,  1.18it/s][I 2021-06-24 10:11:45,121] Trial 8 finished with value: 0.38580508839538313 and parameters: {'num_leaves': 55}. Best is trial 8 with value: 0.38580508839538313.
#
#
#
# num_leaves, val_score: 0.383912:  10%|#         | 2/20 [00:01<00:15,  1.18it/s]
# [116]	valid_0's multi_logloss: 0.653284
# [117]	valid_0's multi_logloss: 0.655355
# [118]	valid_0's multi_logloss: 0.659238
# [119]	valid_0's multi_logloss: 0.663411
# Early stopping, best iteration is:
# [19]	valid_0's multi_logloss: 0.385805
# [1]	valid_0's multi_logloss: 0.572049
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.527924
# [3]	valid_0's multi_logloss: 0.498341
# [4]	valid_0's multi_logloss: 0.475768
# [5]	valid_0's multi_logloss: 0.458229
# [6]	valid_0's multi_logloss: 0.441971
# [7]	valid_0's multi_logloss: 0.428234
# [8]	valid_0's multi_logloss: 0.418872
# [9]	valid_0's multi_logloss: 0.410161
# [10]	valid_0's multi_logloss: 0.403175
# [11]	valid_0's multi_logloss: 0.39672
# [12]	valid_0's multi_logloss: 0.393408
# [13]	valid_0's multi_logloss: 0.389796
# [14]	valid_0's multi_logloss: 0.388304
# [15]	valid_0's multi_logloss: 0.38829
# [16]	valid_0's multi_logloss: 0.386802
# [17]	valid_0's multi_logloss: 0.38742
# [18]	valid_0's multi_logloss: 0.385805
# ...
# [35]	valid_0's multi_logloss: 0.384531
# [36]	valid_0's multi_logloss: 0.383482
# [37]	valid_0's multi_logloss: 0.382071
# [38]	valid_0's multi_logloss: 0.382076
# [39]	valid_0's multi_logloss: 0.381323
# [40]	valid_0's multi_logloss: 0.380716
# [41]	valid_0's multi_logloss: 0.379898
# [42]	valid_0's multi_logloss: 0.380761
# [43]	valid_0's multi_logloss: 0.380227
# [44]	valid_0's multi_logloss: 0.37959
# [45]	valid_0's multi_logloss: 0.380599
# [46]	valid_0's multi_logloss: 0.380773
# [47]	valid_0's multi_logloss: 0.3811
# [48]	valid_0's multi_logloss: 0.381433
# [49]	valid_0's multi_logloss: 0.381982
# [50]	valid_0's multi_logloss: 0.382361
# [51]	valid_0's multi_logloss: 0.382607
# [52]	valid_0's multi_logloss: 0.381988
# [53]	valid_0's multi_logloss: 0.382334
# [54]	valid_0's multi_logloss: 0.382242
# [55]	valid_0's multi_logloss: 0.382918
# [56]	valid_0's multi_logloss: 0.384429
# [57]	valid_0's multi_logloss: 0.385869
# [58]	valid_0's multi_logloss: 0.387739
# [59]	valid_0's multi_logloss: 0.387929
# [60]	valid_0's multi_logloss: 0.388535
# [61]	valid_0's multi_logloss: 0.38749
# [62]	valid_0's multi_logloss: 0.386852
# [63]	valid_0's multi_logloss: 0.3867
# [64]	valid_0's multi_logloss: 0.38631
# [65]	valid_0's multi_logloss: 0.386282
# [66]	valid_0's multi_logloss: 0.387523
# [67]	valid_0's multi_logloss: 0.386304
# [68]	valid_0's multi_logloss: 0.388014
# [69]	valid_0's multi_logloss: 0.387779
# [70]	valid_0's multi_logloss: 0.388218
# [71]	valid_0's multi_logloss: 0.387664
# [72]	valid_0's multi_logloss: 0.386787
# [73]	valid_0's multi_logloss: 0.385385
# [74]	valid_0's multi_logloss: 0.384379
# [75]	valid_0's multi_logloss: 0.383871
# [76]	valid_0's multi_logloss: 0.383928
# [77]	valid_0's multi_logloss: 0.38394
# [78]	valid_0's multi_logloss: 0.384999
# [79]	valid_0's multi_logloss: 0.385775
# [80]	valid_0's multi_logloss: 0.386371
# [81]	valid_0's multi_logloss: 0.386591
# [82]	valid_0's multi_logloss: 0.387071
# [83]	valid_0's multi_logloss: 0.386903
# [84]	valid_0's multi_logloss: 0.387673
# [85]	valid_0's multi_logloss: 0.388774
# [86]	valid_0's multi_logloss: 0.388301
# [87]	valid_0's multi_logloss: 0.388028
# [88]	valid_0's multi_logloss: 0.38684
# [89]	valid_0's multi_logloss: 0.386054
# [90]	valid_0's multi_logloss: 0.386352
# [91]	valid_0's multi_logloss: 0.387517
# [92]	valid_0's multi_logloss: 0.388537
# [93]	valid_0's multi_logloss: 0.390225
# [94]	valid_0's multi_logloss: 0.390735
# [95]	valid_0's multi_logloss: 0.391233
# [96]	valid_0's multi_logloss: 0.391358
# [97]	valid_0's multi_logloss: 0.3913
# [98]	valid_0's multi_logloss: 0.389692
# [99]	valid_0's multi_logloss: 0.388907
# [100]	valid_0's multi_logloss: 0.38895
# [101]	valid_0's multi_logloss: 0.389139
# [102]	valid_0's multi_logloss: 0.390037
# [103]	valid_0's multi_logloss: 0.390587
# [104]	valid_0's multi_logloss: 0.390821
# [105]	valid_0's multi_logloss: 0.391655
# [106]	valid_0's multi_logloss: 0.391938
# [107]	valid_0's multi_logloss: 0.392556
# [108]	valid_0's multi_logloss: 0.392917
# [109]	valid_0's multi_logloss: 0.393616
# [110]	valid_0's multi_logloss: 0.394121
# [111]	valid_0's multi_logloss: 0.394589
# [112]	valid_0's multi_logloss: 0.395086
# [113]	valid_0's multi_logloss: 0.395512
# [114]	valid_0's multi_logloss: 0.396644
# [115]	valid_0's multi_logloss: 0.397045
# [116]	valid_0's multi_logloss: 0.398541
# [117]	valid_0's multi_logloss: 0.398541
# [118]	valid_0's multi_logloss: 0.399394
# [119]	valid_0's multi_logloss: 0.400931
# [120]	valid_0's multi_logloss: 0.401478
# [121]	valid_0's multi_logloss: 0.401301
# [122]	valid_0's multi_logloss: 0.401676
# [123]	valid_0's multi_logloss: 0.40206
# [124]	valid_0's multi_logloss: 0.402457
# [125]	valid_0's multi_logloss: 0.40278
# [126]	valid_0's multi_logloss: 0.400885
# [127]	valid_0's multi_logloss: 0.399914
# [128]	valid_0's multi_logloss: 0.399033
# min_data_in_leaf, val_score: 0.360803:  60%|######    | 3/5 [00:00<00:00,  5.36it/s][I 2021-06-24 10:12:00,079] Trial 65 finished with value: 0.37959013313290046 and parameters: {'min_child_samples': 100}. Best is trial 64 with value: 0.37199095273058475.
# min_data_in_leaf, val_score: 0.360803:  80%|########  | 4/5 [00:00<00:00,  5.42it/s]
# [129]	valid_0's multi_logloss: 0.398511
# [130]	valid_0's multi_logloss: 0.398165
# [131]	valid_0's multi_logloss: 0.399359
# [132]	valid_0's multi_logloss: 0.400233
# [133]	valid_0's multi_logloss: 0.400862
# [134]	valid_0's multi_logloss: 0.401567
# [135]	valid_0's multi_logloss: 0.402021
# [136]	valid_0's multi_logloss: 0.403192
# [137]	valid_0's multi_logloss: 0.402492
# [138]	valid_0's multi_logloss: 0.403016
# [139]	valid_0's multi_logloss: 0.40427
# [140]	valid_0's multi_logloss: 0.405454
# [141]	valid_0's multi_logloss: 0.405765
# [142]	valid_0's multi_logloss: 0.405737
# [143]	valid_0's multi_logloss: 0.405695
# [144]	valid_0's multi_logloss: 0.405397
# Early stopping, best iteration is:
# [44]	valid_0's multi_logloss: 0.37959
# [1]	valid_0's multi_logloss: 0.573337
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.530761
# [3]	valid_0's multi_logloss: 0.501833
# [4]	valid_0's multi_logloss: 0.480479
# [5]	valid_0's multi_logloss: 0.463888
# [6]	valid_0's multi_logloss: 0.445643
# [7]	valid_0's multi_logloss: 0.431643
# [8]	valid_0's multi_logloss: 0.421492
# [9]	valid_0's multi_logloss: 0.40939
# [10]	valid_0's multi_logloss: 0.399945
# [11]	valid_0's multi_logloss: 0.39336
# [12]	valid_0's multi_logloss: 0.388821
# [13]	valid_0's multi_logloss: 0.38562
# [14]	valid_0's multi_logloss: 0.383291
# [15]	valid_0's multi_logloss: 0.382079
# [16]	valid_0's multi_logloss: 0.377631
# [17]	valid_0's multi_logloss: 0.375007
# [18]	valid_0's multi_logloss: 0.372188
# [19]	valid_0's multi_logloss: 0.370908
# [20]	valid_0's multi_logloss: 0.370986
# [21]	valid_0's multi_logloss: 0.369057
# [22]	valid_0's multi_logloss: 0.368033
# [23]	valid_0's multi_logloss: 0.36749
# [24]	valid_0's multi_logloss: 0.367697
# [25]	valid_0's multi_logloss: 0.368327
# [26]	valid_0's multi_logloss: 0.369572
# [27]	valid_0's multi_logloss: 0.370434
# [28]	valid_0's multi_logloss: 0.373627
# [29]	valid_0's multi_logloss: 0.376223
# [30]	valid_0's multi_logloss: 0.380356
# [31]	valid_0's multi_logloss: 0.381557
# [32]	valid_0's multi_logloss: 0.38365
# [33]	valid_0's multi_logloss: 0.386404
# [34]	valid_0's multi_logloss: 0.389588
# [35]	valid_0's multi_logloss: 0.391019
# [36]	valid_0's multi_logloss: 0.390454
# [37]	valid_0's multi_logloss: 0.389356
# [38]	valid_0's multi_logloss: 0.390771
# [39]	valid_0's multi_logloss: 0.391499
# [40]	valid_0's multi_logloss: 0.391994
# [41]	valid_0's multi_logloss: 0.393996
# [42]	valid_0's multi_logloss: 0.396283
# [43]	valid_0's multi_logloss: 0.397765
# [44]	valid_0's multi_logloss: 0.398002
# [45]	valid_0's multi_logloss: 0.400556
# [46]	valid_0's multi_logloss: 0.402535
# [47]	valid_0's multi_logloss: 0.402167
# [115]	valid_0's multi_logloss: 0.465919
# [116]	valid_0's multi_logloss: 0.467975
# [117]	valid_0's multi_logloss: 0.470484
# [118]	valid_0's multi_logloss: 0.473122
# [119]	valid_0's multi_logloss: 0.475813
# [120]	valid_0's multi_logloss: 0.476933
# [121]	valid_0's multi_logloss: 0.477707
# [122]	valid_0's multi_logloss: 0.479684
# [123]	valid_0's multi_logloss: 0.480117
# Early stopping, best iteration is:
# [23]	valid_0's multi_logloss: 0.36749
# [I 2021-06-24 10:12:00,261] Trial 66 finished with value: 0.36748995743785406 and parameters: {'min_child_samples': 25}. Best is trial 66 with value: 0.36748995743785406.
# min_data_in_leaf, val_score: 0.360803: 100%|##########| 5/5 [00:00<00:00,  5.46it/s][I 2021-06-24 10:12:00,441] Trial 67 finished with value: 0.3714546365530966 and parameters: {'min_child_samples': 50}. Best is trial 66 with value: 0.36748995743785406.
# min_data_in_leaf, val_score: 0.360803: 100%|##########| 5/5 [00:00<00:00,  5.31it/s]
# [1]	valid_0's multi_logloss: 0.57637
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.536304
# [3]	valid_0's multi_logloss: 0.50756
# [4]	valid_0's multi_logloss: 0.486156
# [5]	valid_0's multi_logloss: 0.469164
# [6]	valid_0's multi_logloss: 0.455541
# [7]	valid_0's multi_logloss: 0.443604
# [8]	valid_0's multi_logloss: 0.434898
# [9]	valid_0's multi_logloss: 0.427038
# [10]	valid_0's multi_logloss: 0.41958
# [11]	valid_0's multi_logloss: 0.411686
# [12]	valid_0's multi_logloss: 0.407147
# [13]	valid_0's multi_logloss: 0.402585
# [14]	valid_0's multi_logloss: 0.399976
# [15]	valid_0's multi_logloss: 0.39857
# [16]	valid_0's multi_logloss: 0.392964
# [17]	valid_0's multi_logloss: 0.389225
# [18]	valid_0's multi_logloss: 0.385344
# [19]	valid_0's multi_logloss: 0.382558
# [20]	valid_0's multi_logloss: 0.381321
# [21]	valid_0's multi_logloss: 0.379635
# [22]	valid_0's multi_logloss: 0.378207
# [23]	valid_0's multi_logloss: 0.376516
# [24]	valid_0's multi_logloss: 0.375162
# [25]	valid_0's multi_logloss: 0.37448
# [26]	valid_0's multi_logloss: 0.372876
# [27]	valid_0's multi_logloss: 0.371938
# [28]	valid_0's multi_logloss: 0.372598
# [29]	valid_0's multi_logloss: 0.371819
# [30]	valid_0's multi_logloss: 0.372906
# [31]	valid_0's multi_logloss: 0.373939
# [32]	valid_0's multi_logloss: 0.375445
# [33]	valid_0's multi_logloss: 0.376101
# [34]	valid_0's multi_logloss: 0.377376
# [35]	valid_0's multi_logloss: 0.377388
# [36]	valid_0's multi_logloss: 0.376369
# [37]	valid_0's multi_logloss: 0.375429
# [38]	valid_0's multi_logloss: 0.374261
# [39]	valid_0's multi_logloss: 0.373364
# [40]	valid_0's multi_logloss: 0.373233
# [41]	valid_0's multi_logloss: 0.373559
# [42]	valid_0's multi_logloss: 0.374251
# [43]	valid_0's multi_logloss: 0.372364
# [44]	valid_0's multi_logloss: 0.371518
# [45]	valid_0's multi_logloss: 0.371455
# [46]	valid_0's multi_logloss: 0.372043
# [47]	valid_0's multi_logloss: 0.372558
# [48]	valid_0's multi_logloss: 0.37275
# [49]	valid_0's multi_logloss: 0.373899
# [50]	valid_0's multi_logloss: 0.374719
# [51]	valid_0's multi_logloss: 0.377312
# [52]	valid_0's multi_logloss: 0.37718
# [53]	valid_0's multi_logloss: 0.377641
# [54]	valid_0's multi_logloss: 0.378101
# [55]	valid_0's multi_logloss: 0.380043
# [56]	valid_0's multi_logloss: 0.381684
# [57]	valid_0's multi_logloss: 0.383674
# [58]	valid_0's multi_logloss: 0.384554
# [59]	valid_0's multi_logloss: 0.384585
# [60]	valid_0's multi_logloss: 0.386645
# [61]	valid_0's multi_logloss: 0.385892
# [62]	valid_0's multi_logloss: 0.385851
# [63]	valid_0's multi_logloss: 0.386617
# [64]	valid_0's multi_logloss: 0.387099
# [65]	valid_0's multi_logloss: 0.387937
# [66]	valid_0's multi_logloss: 0.387557
# [67]	valid_0's multi_logloss: 0.387211
# [68]	valid_0's multi_logloss: 0.387673
# [69]	valid_0's multi_logloss: 0.388314
# [70]	valid_0's multi_logloss: 0.388188
# [71]	valid_0's multi_logloss: 0.388295
# [72]	valid_0's multi_logloss: 0.388854
# [73]	valid_0's multi_logloss: 0.389351
# [74]	valid_0's multi_logloss: 0.38997
# [75]	valid_0's multi_logloss: 0.389398
# [76]	valid_0's multi_logloss: 0.388883
# [77]	valid_0's multi_logloss: 0.38873
# [78]	valid_0's multi_logloss: 0.389388
# [79]	valid_0's multi_logloss: 0.389868
# [80]	valid_0's multi_logloss: 0.390783
# [81]	valid_0's multi_logloss: 0.391953
# [82]	valid_0's multi_logloss: 0.391687
# [83]	valid_0's multi_logloss: 0.392163
# [84]	valid_0's multi_logloss: 0.391121
# [85]	valid_0's multi_logloss: 0.390128
# [86]	valid_0's multi_logloss: 0.390582
# [87]	valid_0's multi_logloss: 0.390821
# [88]	valid_0's multi_logloss: 0.390173
# [89]	valid_0's multi_logloss: 0.390081
# [90]	valid_0's multi_logloss: 0.390177
# [91]	valid_0's multi_logloss: 0.392302
# [92]	valid_0's multi_logloss: 0.394912
# [93]	valid_0's multi_logloss: 0.398346
# [94]	valid_0's multi_logloss: 0.400788
# [95]	valid_0's multi_logloss: 0.403106
# [96]	valid_0's multi_logloss: 0.40374
# [97]	valid_0's multi_logloss: 0.403966
# [98]	valid_0's multi_logloss: 0.404879
# [99]	valid_0's multi_logloss: 0.404249
# [100]	valid_0's multi_logloss: 0.405982
# [101]	valid_0's multi_logloss: 0.406106
# [102]	valid_0's multi_logloss: 0.40711
# [103]	valid_0's multi_logloss: 0.408844
# [104]	valid_0's multi_logloss: 0.409524
# [105]	valid_0's multi_logloss: 0.409735
# [106]	valid_0's multi_logloss: 0.410186
# [107]	valid_0's multi_logloss: 0.410732
# [108]	valid_0's multi_logloss: 0.411199
# [109]	valid_0's multi_logloss: 0.411604
# [110]	valid_0's multi_logloss: 0.412387
# [111]	valid_0's multi_logloss: 0.41272
# [112]	valid_0's multi_logloss: 0.411867
# [113]	valid_0's multi_logloss: 0.412616
# [114]	valid_0's multi_logloss: 0.413482
# [115]	valid_0's multi_logloss: 0.414286
# [116]	valid_0's multi_logloss: 0.415642
# [117]	valid_0's multi_logloss: 0.417822
# [118]	valid_0's multi_logloss: 0.419454
# [119]	valid_0's multi_logloss: 0.420605
# [120]	valid_0's multi_logloss: 0.420425
# [121]	valid_0's multi_logloss: 0.421886
# [122]	valid_0's multi_logloss: 0.423357
# [123]	valid_0's multi_logloss: 0.42426
# [124]	valid_0's multi_logloss: 0.426334
# [125]	valid_0's multi_logloss: 0.426445
# [126]	valid_0's multi_logloss: 0.424024
# [127]	valid_0's multi_logloss: 0.422261
# [128]	valid_0's multi_logloss: 0.421343
# [129]	valid_0's multi_logloss: 0.42053
# [130]	valid_0's multi_logloss: 0.418658
# [131]	valid_0's multi_logloss: 0.420485
# [132]	valid_0's multi_logloss: 0.422671
# [133]	valid_0's multi_logloss: 0.424599
# [134]	valid_0's multi_logloss: 0.427704
# [135]	valid_0's multi_logloss: 0.430113
# [136]	valid_0's multi_logloss: 0.431068
# [137]	valid_0's multi_logloss: 0.430286
# [138]	valid_0's multi_logloss: 0.42963
# [139]	valid_0's multi_logloss: 0.429763
# [140]	valid_0's multi_logloss: 0.430492
# [141]	valid_0's multi_logloss: 0.430777
# [142]	valid_0's multi_logloss: 0.43007
# [143]	valid_0's multi_logloss: 0.429895
# [144]	valid_0's multi_logloss: 0.430136
# [145]	valid_0's multi_logloss: 0.430109
# Early stopping, best iteration is:
# [45]	valid_0's multi_logloss: 0.371455

# %%
best.params
# Out:
# {'objective': 'multiclass',
#  'metric': 'multi_logloss',
#  'num_class': 3,
#  'verbosity': -1,
#  'boosting_type': 'gbdt',
#  'feature_pre_filter': False,
#  'lambda_l1': 0.1312125392410861,
#  'lambda_l2': 0.06013807926031679,
#  'num_leaves': 22,
#  'feature_fraction': 0.8,
#  'bagging_fraction': 0.6362990005586665,
#  'bagging_freq': 5,
#  'min_child_samples': 20,
#  'num_iterations': 1000,
#  'early_stopping_round': 100}

# %%
best.best_iteration
# Out:
# 23

# %%
best.best_score
# Out:
# defaultdict(collections.OrderedDict,
#             {'valid_0': OrderedDict([('multi_logloss', 0.3608029846312686)])})

# %%
# 勾配ブースティング決定木回帰モデルの学習
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

from lightgbm import LGBMClassifier
nbr = LGBMClassifier(
                    learning_rate = 0.01,
                    n_estimators = 1000,
                    num_leaves = 22,
                    min_child_samples = 20,
                    bagging_fraction = 0.636,
                    bagging_freq = 5,
                    feature_fraction = 0.8,
                    lambda_l1= 0.131,
                    lambda_l2 = 0.060
)
nbr.fit(X_train, y_train,
        eval_set = (x_train, y_train), 
        early_stopping_rounds = 5, 
        verbose = 500)     # verboseは学習の様子をprintするiterationの間隔
# Out:
# Training until validation scores don't improve for 5 rounds
# Early stopping, best iteration is:
# [17]	valid_0's multi_logloss: 0.671971
# LGBMClassifier(bagging_fraction=0.636, bagging_freq=5, feature_fraction=0.8,
#                lambda_l1=0.131, lambda_l2=0.06, learning_rate=0.01,
#                n_estimators=1000, num_leaves=22)

# %%
from sklearn.metrics import f1_score

f1_train = f1_score(y_train, nbr.predict(x_train), average='macro')
f1_test = f1_score(y_val, nbr.predict(x_val), average='macro')

# 評価結果の表示
print("f1_train:", f1_train, "f1_test", f1_test)
# Out:
# f1_train: 0.29256174192605583 f1_test 0.2956521739130435

# %%
test = test_df.drop(columns=['id'])

test_X = pd.get_dummies(test)

test_X = test_X.drop(columns=['sex_female','smoker_no','region_southwest'])

test_X['generation'] = test_X.age.apply(lambda x: age_transform(x))
test_X['have_children'] = test_X.children.apply(lambda x: children_transform(x))

test_X_children =  test_X.groupby(['children']).agg(children_bmi_mean=('bmi','mean'),
                                                                        children_bmi_std=('bmi', 'std'),
                                                                        children_bmi_med=('bmi', 'median'),
                                                                        children_age_mean=('age','mean'),
                                                                        children_age_std=('age', 'std'),
                                                                        children_age_med=('age','median')
                                         ).reset_index()
test_X = pd.merge(test_X, test_X_children, on='children', how='left')

test_X_smoker =  test_X.groupby(['smoker_yes']).agg(
    smoker_bmi_mean=('bmi','mean'),
    smoker_bmi_std=('bmi', 'std'),
    smoker_bmi_med=('bmi', 'median'),
    smoker_age_mean=('age','mean'),
    smoker_age_std=('age', 'std'),
    smoker_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_smoker, on='smoker_yes', how='left')

test_X_northeast =  test_X.groupby(['region_northeast']).agg(
    northeast_bmi_mean=('bmi','mean'),
    northeast_bmi_std=('bmi', 'std'),
    northeast_bmi_med=('bmi', 'median'),
    northeast_age_mean=('age','mean'),
    northeast_age_std=('age', 'std'),
    northeast_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_northeast, on='region_northeast', how='left')

test_X_northwest =  test_X.groupby(['region_northwest']).agg(
    northwest_bmi_mean=('bmi','mean'),
    northwest_bmi_std=('bmi', 'std'),
    northwest_bmi_med=('bmi', 'median'),
    northwest_age_mean=('age','mean'),
    northwest_age_std=('age', 'std'),
    northwest_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_northwest, on='region_northwest', how='left')

test_X_southeast =  test_X.groupby(['region_southeast']).agg(
    southeast_bmi_mean=('bmi','mean'),
    southeast_bmi_std=('bmi', 'std'),
    southeast_bmi_med=('bmi', 'median'),
    southeast_age_mean=('age','mean'),
    southeast_age_std=('age', 'std'),
    southeast_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_southeast, on='region_southeast', how='left')

test_X_gen_sex =  test_X.groupby(['generation','sex_male']).agg(
    gen_sex_bmi_mean=('bmi','mean'),
    gen_sex_bmi_std=('bmi', 'std'),
    gen_sex_bmi_med=('bmi', 'median')
).reset_index()

test_X = pd.merge(test_X, test_X_gen_sex, on=['generation','sex_male'], how='left')

test_X_have =  test_X.groupby(['have_children']).agg(
    have_bmi_mean=('bmi','mean'),
    have_bmi_std=('bmi', 'std'),
    have_bmi_med=('bmi', 'median'),
    have_age_mean=('age','mean'),
    have_age_std=('age', 'std'),
    have_age_med=('age','median')
).reset_index()

test_X = pd.merge(test_X, test_X_have, on='have_children', how='left')


test_X = test_X[['bmi', 'age', 'smoker_yes', 'smoker_age_mean', 'gen_sex_bmi_mean']]

# %%
sample_submit[1] = nbr.predict(test_X)
sample_submit.to_csv('submit_lgbm_downF.csv', header=None)
sample_submit.head()
# Out:
#     1
# 0
# 13  0
# 23  0
# 27  0
# 28  0
# 29  0
